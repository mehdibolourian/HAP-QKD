# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
init_setup_real_skr_plot()
# Out:
#        Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0         0.0     279.000000     49.000000  25000.00000
# 1        90.0     278.999734     49.000680  24952.42453
# 2       180.0     278.999332     49.001837  24829.60817
# 3       270.0     278.998942     49.003267  24710.89433
# 4       360.0     278.998611     49.004939  24591.76252
# ...       ...            ...           ...          ...
# 1050  86040.0     279.624762     49.152323  24307.94390
# 1051  86130.0     279.625373     49.153110  24336.53860
# 1052  86220.0     279.625956     49.153910  24338.49787
# 1053  86310.0     279.626516     49.154720  24358.29581
# 1054  86400.0     279.627055     49.155538  24350.33468
#
# [961 rows x 4 columns]
# ([<data.gs at 0x13649a560>],
#  [<data.hap at 0x13649a5f0>],
#  [<data.link at 0x104df71c0>, <data.link at 0x104df76d0>],
#  [])

# %%
# plot_loss_distance(1,0,0,0)

# %%
# plot_skr_distance()

# %%
# plot_skr()

# %%
# plot_skr_eta_stratotegic_real()
