# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

nodes = gnodes + hnodes
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1      900.0     278.997982     49.018421  23951.48919
# 2     1800.0     278.991146     49.029046  23678.70919
# 5     2700.0     278.982578     49.035804  23675.55769
# 6     3600.0     278.974006     49.042329  23672.57558
# ..       ...            ...           ...          ...
# 182  82800.0     279.593425     49.128661  24030.70810
# 185  83700.0     279.604025     49.134353  24032.65500
# 186  84600.0     279.612554     49.141021  24030.74921
# 189  85500.0     279.620485     49.147937  24029.72337
# 190  86400.0     279.627055     49.155538  24350.33468
#
# [97 rows x 4 columns]
# ⏱️ Calculating K_MAX from t=0 to t=95
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# %%
# ---------- Hyperparams ----------
# GAMMA = 0.99
# GAE_LAMBDA = 0.95
# CLIP = 0.2
# LR = 3e-4
# EPOCHS = 4
# BATCH_SIZE = 64
# ENTROPY_COEF_INITIAL = 0.05         # >>> CHANGE - will decay over training
# ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
# ENTROPY_DECAY = 0.995               # >>> CHANGE
# VALUE_COEF = 0.5

GAMMA = 0.99
LR = 1e-4
CLIP = 0.2
EPOCHS = 4
BATCH_SIZE = 256
ENTROPY_COEF_INITIAL = 0.01
ENTROPY_COEF_MIN = 0.001
ENTROPY_DECAY = 0.999
GAE_LAMBDA = 0.95
VALUE_COEF = 0.5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# def build_state_vector_for_time(state_t, links, t, n_nodes=len(gnodes), normalize=True):
#     """
#     Build state vector for the QKD environment.

#     state_t["a"]: dict or list of QKP (stored key bits) for each link.
#     state_t["demands"]: list of demand objects with attributes (K_REQ, n1, n2).

#     Output vector structure:
#         [ QKP_link0, ..., QKP_linkL-1,
#           onehot_src_demand0..., onehot_dst_demand0..., KREQ_0,
#           onehot_src_demand1..., onehot_dst_demand1..., KREQ_1,
#           ... ]

#     Args:
#         state_t: dict for time t
#         links: list of link objects (or identifiers)
#         n_nodes: total number of GS/HAP nodes (used for one-hot encoding)
#         normalize: normalize QKP and KREQ values to [0, 1] range if True
#     """
#     # --- QKP per link ---
#     a_vec = np.array(
#         [state_t.get("a", {}).get(l, 0.0) for l in range(len(links))],
#         dtype=np.float32
#     )

#     # normalize QKP values if desired
#     if normalize and len(a_vec) > 0:
#         max_qkp = np.max(a_vec) if np.max(a_vec) > 0 else 1.0
#         a_vec = a_vec / max_qkp

#     # --- Encode demands ---
#     d_vec = []
#     for d in state_t.get("demands", []):
#         # normalize K_REQ
#         kreq = float(d.K_REQ[t])
#         if normalize and kreq > 0:
#             kreq = kreq / (kreq + 1e-6)  # simple scaling to (0,1)
#         # one-hot encode endpoints if n_nodes provided
#         if n_nodes is not None:
#             onehot_src = np.zeros(n_nodes, dtype=np.float32)
#             onehot_dst = np.zeros(n_nodes, dtype=np.float32)
#             if 0 <= gnodes.index(d.n1) < n_nodes:
#                 onehot_src[gnodes.index(d.n1)] = 1.0
#             if 0 <= gnodes.index(d.n2) < n_nodes:
#                 onehot_dst[gnodes.index(d.n2)] = 1.0
#             d_vec.extend(onehot_src.tolist() + onehot_dst.tolist() + [kreq])
#         else:
#             # fallback to simpler encoding if node info omitted
#             d_vec.append(kreq)

#     # --- Concatenate ---
#     state_vector = np.concatenate([a_vec, np.array(d_vec, dtype=np.float32)])
#     return state_vector

def build_state_vector_for_time(state_t, links, t, n_gnodes=len(gnodes), normalize=True, f_qkp=True):
    """
    Build state vector for the QKD environment.

    Includes:
    - QKP per link (normalized if normalize=True)
    - K_MAX per link (capacity)
    - For each demand: one-hot source, one-hot destination, normalized K_REQ

    State vector format:
    [ QKP_link0 .. QKP_link(L-1),
      KMAX_link0 .. KMAX_link(L-1),
      (src one-hot, dst one-hot, KREQ_demand0), ... ]
    """

    # -------------------------------
    # QKP / stored key bits per link
    # -------------------------------
    if f_qkp:
        a_vec = np.array(
            [state_t.get("a", {}).get(idx_l, 0.0) for idx_l in range(len(links))],
            dtype=np.float32
        )
    
        if normalize:
            #max_qkp = np.max(a_vec) if np.max(a_vec) > 0 else 1.0
            a_vec = [np.log10(1 + a) / 10 for a in a_vec] #a_vec / max_qkp

    # -----------------------------------------
    # Link Capacity (K_MAX per link)
    # -----------------------------------------
    if normalize:
        K_MAX_MAX = 1e9 #max(l.K_MAX[t] for l in links) + 1e-9  # avoid /0
        kmax_vec = np.array([l.K_MAX[t] / K_MAX_MAX for l in links], dtype=np.float32)
    else:
        kmax_vec = np.array([l.K_MAX[t] for l in links], dtype=np.float32)

    # ---------------------------
    # Encode demand information
    # ---------------------------
    #K_REQ_MAX = max(d.K_REQ[t] for d in demands) + 1e-9

    d_vec = []

    # Loop over EVERY ordered GS pair (i → j, i ≠ j)
    for src in gnodes:
        for dst in gnodes:
            if src == dst:
                continue

            # Check whether there is a demand for this exact pair
            matched = next(
                (d for d in state_t.get("demands", [])
                 if d.n1 == src and d.n2 == dst),
                None
            )

            src_idx = gnodes.index(src)
            dst_idx = gnodes.index(dst)

            src_norm = (src_idx + 1) / n_gnodes
            dst_norm = (dst_idx + 1) / n_gnodes

            if matched:
                # Active demand exists
                kreq = float(matched.K_REQ[t])
                if normalize:
                    #kreq = kreq / K_REQ_MAX
                    kreq = np.log10(1 + kreq) / 5

                d_vec.extend([src_norm, dst_norm, kreq, 1.0])

            else:
                # No demand for this pair
                d_vec.extend([src_norm, dst_norm, 0.0, 0.0])

    # ---------------------------
    # Concatenate full state
    # ---------------------------
    if f_qkp:
        state_vector = np.concatenate(
            [a_vec, kmax_vec, np.array(d_vec, dtype=np.float32)]
        )
    else:
        state_vector = np.concatenate(
            [kmax_vec, np.array(d_vec, dtype=np.float32)]
        )

    return state_vector

def heuristic_policy(state_t, links, t):
    action = np.zeros(len(links), dtype=int)
    nodes_taken_rx = np.zeros(len(nodes), dtype=int)
    nodes_taken_tx = np.zeros(len(nodes), dtype=int)

    demands_sorted = sorted(
        state_t["demands"],
        key=lambda d: d.K_REQ[t],
        reverse=True   # largest demand first
    )
    for d in demands_sorted:
        src = d.n1
        dst = d.n2

        done = 0
        current_node = src
        while done == 0:
            adj_links = sorted(
                (l for l in links
                    if l.n1 == current_node and l.K_MAX[t] >= d.K_REQ[t] and state_t["a"][links.index(l)] <= d.K_REQ[t] and nodes_taken_tx[nodes.index(l.n1)] == 0 and nodes_taken_rx[nodes.index(l.n2)] == 0),
                key=lambda l: l.K_MAX[t],
                reverse=True
            )
            if adj_links != []:
                action[links.index(adj_links[0])] = 1
                current_node = adj_links[0].n2
                nodes_taken_rx[nodes.index(adj_links[0].n2)] = 1
                nodes_taken_tx[nodes.index(adj_links[0].n1)] = 1
            else:
                done = 1
                
            if current_node == dst:
                done = 1

    return action

# ---------- Actor-Critic network for multi-binary action ----------
class ActorCriticBinary(nn.Module):
    def __init__(self, state_dim, action_dim, hidden=128):
        super().__init__()
        # self.net = nn.Sequential(
        #     nn.Linear(state_dim, hidden),
        #     nn.ReLU(),
        #     nn.Linear(hidden, hidden),
        #     nn.ReLU()
        # )
        # # outputs logits for Bernoulli per action dimension
        # self.logit_head = nn.Linear(hidden, action_dim)
        # # critic outputs a scalar value
        # self.critic = nn.Sequential(
        #     nn.Linear(state_dim, hidden//2),
        #     nn.ReLU(),
        #     nn.Linear(hidden//2, 1)
        # )
        self.trunk = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.LayerNorm(hidden),
            nn.ReLU()
        )
        
        self.actor = nn.Linear(hidden, action_dim)
        self.critic = nn.Linear(hidden, 1)

    def forward(self, state):
        """
        state: tensor of shape [batch, state_dim]
        returns:
            logits: [batch, action_dim]
            value: [batch, 1]
        """
        # h = self.net(state)
        # logits = self.logit_head(h)
        # value = self.critic(state)
        h = self.trunk(state)
        logits = self.actor(h)
        value = self.critic(h).squeeze(-1)
        return logits, value.squeeze(-1)

# ---------- PPO Agent for binary actions ----------
class PPOBinaryAgent:
    def __init__(self, state_dim, action_dim, lr=LR):
        self.model = ActorCriticBinary(state_dim, action_dim).to(DEVICE)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.action_dim = action_dim

    def select_action(self, state_vec, mask=None):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        logits, value = self.model(s)  # [1, action_dim], [1]

        probs = torch.sigmoid(logits)
        m = torch.distributions.Bernoulli(probs)
        action = m.sample()
        logp = m.log_prob(action).sum(dim=-1)

        return action.squeeze(0).cpu().numpy().astype(int), logp.squeeze(0).detach(), value.squeeze(0).detach()

    def evaluate_action(self, state_vec, action_vec):
        """
        Evaluate log-prob and value of a GIVEN action (heuristic or policy).
        """
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        a = torch.tensor(action_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    
        logits, value = self.model(s)
        probs = torch.sigmoid(logits)
    
        dist = torch.distributions.Bernoulli(probs)
        logp = dist.log_prob(a).sum(dim=-1)
    
        return logp.squeeze(0).detach(), value.squeeze(0).detach()

    def compute_gae(self, rewards, values, dones, gamma=GAMMA, lam=GAE_LAMBDA):
        # rewards: list length T
        # values: tensor shape [T+1] containing state values; values[-1] is bootstrap for final
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            delta = rewards[t] + gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + gamma * lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
        returns = adv + values[:-1]
        return adv, returns

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef):  # >>> CHANGE - new param
        """
        states: tensor [N, state_dim]
        actions: tensor [N, action_dim] (0/1)
        old_logps: tensor [N] (scalar log prob of full action vector)
        returns: tensor [N]
        advantages: tensor [N]
        """
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        N = states.shape[0]
        idxs = np.arange(N)
        for _ in range(EPOCHS):
            np.random.shuffle(idxs)
            for start in range(0, N, BATCH_SIZE):
                batch_idx = idxs[start:start + BATCH_SIZE]
                b_states = states[batch_idx].to(DEVICE)
                b_actions = actions[batch_idx].to(DEVICE).float()
                b_old_logps = old_logps[batch_idx].to(DEVICE)
                b_returns = returns[batch_idx].to(DEVICE)
                b_adv = advantages[batch_idx].to(DEVICE)

                logits, values = self.model(b_states)
                probs = torch.sigmoid(logits)
                dist = torch.distributions.Bernoulli(probs)
                new_logp = dist.log_prob(b_actions).sum(dim=-1)
                entropy = dist.entropy().sum(dim=-1).mean()

                ratio = torch.exp(new_logp - b_old_logps)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - CLIP, 1.0 + CLIP) * b_adv
                actor_loss = -torch.min(surr1, surr2).mean()
                critic_loss = F.mse_loss(values, b_returns)

                loss = actor_loss + VALUE_COEF * critic_loss - entropy_coef * entropy  # >>> CHANGE

                self.optimizer.zero_grad()
                loss.backward()

                # ----- MANDATORY FOR GAT -----
                #torch.nn.utils.clip_grad_norm_(self.model.parameters(), 0.5)
                
                self.optimizer.step()

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T
action_dim = n_links

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(state[0], links, 0, f_qkp=f_qkp)
state_dim = len(state_vector_example)

agent = PPOBinaryAgent(state_dim, action_dim, lr=LR)

# Training hyperparams
num_episodes = 9000
episode_len = len(syst.T)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

# WARM_EPISODES  = 500
# DECAY_EPISODES = 3000

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]
    state[0]["demands"] = demands.copy()

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf = []
    actions_buf = []
    logps_buf = []
    rewards_buf = []
    dones_buf = []
    values_buf = []

    total_reward = 0.0

    mean_kbps_rand = random.randint(1, 2)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.1*mean_kbps_rand, amp=0.5, noise_std=0, pattern="sinusoidal")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    
    # Inside your episode loop
    # Inside your episode loop
    if ep < 3000:
        k = 1  # Keep it simple for "Warm Up"
    elif ep < 6000:
        k = 2  # Keep it simple for "Warm Up"
    else:
        k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity
    
    demands = random.sample(demands_space, k)
    random.shuffle(demands)

    for t in syst.T:
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t, f_qkp=f_qkp)

        #p_h = max(0.0, 1 - ep / DECAY_EPISODES)
        #use_heuristic = (np.random.rand() < p_h)

        # if ep < WARM_EPISODES:
        # #if use_heuristic:
        #     action_vec = heuristic_policy(state[t], links, t)
        
        #     # IMPORTANT: still evaluate logp and value using PPO policy
        #     logp, value = agent.evaluate_action(s_vec, action_vec)
        # else:
        #     action_vec, logp, value = agent.select_action(s_vec)
        
        action_vec, logp, value = agent.select_action(s_vec)

        # convert flat action vector to dictionary
        action[t] = {}
        for idx_l in range(n_links):
            action[t][idx_l] = int(action_vec[idx_l])

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes
        for idx_h, h in enumerate(hnodes):
            sum_tx[idx_h] = sum(action[t][idx_l]
                                for idx_l, l in enumerate(links)
                                if  l.n1 == h
                               )

            sum_rx[idx_h] = sum(action[t][idx_l]
                                for idx_l, l in enumerate(links)
                                if  l.n2 == h
                               )
            
            check_tx = check_tx and (sum_tx[idx_h] <= h.N_TX)
            check_rx = check_rx and (sum_rx[idx_h] <= h.N_RX)

            # if not check_tx or not check_rx:
            #     # print("Violated maximum RX/TX constraints!")
            #     break

        if check_tx and check_rx:
            solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, action, t, f_qkp)
        else:
            reward_t = -sum(sum_tx[idx_h] + sum_rx[idx_h] for idx_h, h in enumerate(hnodes)) / len(hnodes) / len(gnodes) / 2 #-10

        #print(f"reward_t: {reward_t}")

        reward[t] = reward_t
        total_reward += reward_t

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        actions_buf.append(torch.tensor(action_vec, dtype=torch.float32))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(state[-1], links, t, f_qkp=f_qkp)
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor, final_value.view(1)])   # shape [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}")

# === Plot learning curve ===
plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/9000, total reward: -48.646, entropy_coef: 0.0100, demands: 1
# Episode 2/9000, total reward: -47.375, entropy_coef: 0.0100, demands: 1
# Episode 3/9000, total reward: -47.354, entropy_coef: 0.0100, demands: 1
# Episode 4/9000, total reward: -46.417, entropy_coef: 0.0100, demands: 1
# Episode 5/9000, total reward: -48.125, entropy_coef: 0.0100, demands: 1
# Episode 6/9000, total reward: -47.333, entropy_coef: 0.0099, demands: 1
# Episode 7/9000, total reward: -48.292, entropy_coef: 0.0099, demands: 1
# Episode 8/9000, total reward: -47.812, entropy_coef: 0.0099, demands: 1
# Episode 9/9000, total reward: -48.083, entropy_coef: 0.0099, demands: 1
# Episode 10/9000, total reward: -47.667, entropy_coef: 0.0099, demands: 1
# Episode 11/9000, total reward: -46.750, entropy_coef: 0.0099, demands: 1
# Episode 12/9000, total reward: -47.917, entropy_coef: 0.0099, demands: 1
# Episode 13/9000, total reward: -49.042, entropy_coef: 0.0099, demands: 1
# Episode 14/9000, total reward: -49.208, entropy_coef: 0.0099, demands: 1
# Episode 15/9000, total reward: -48.917, entropy_coef: 0.0099, demands: 1
# Episode 16/9000, total reward: -48.500, entropy_coef: 0.0098, demands: 1
# Episode 17/9000, total reward: -48.396, entropy_coef: 0.0098, demands: 1
# Episode 18/9000, total reward: -48.125, entropy_coef: 0.0098, demands: 1
# Episode 19/9000, total reward: -48.854, entropy_coef: 0.0098, demands: 1
# Episode 20/9000, total reward: -48.854, entropy_coef: 0.0098, demands: 1
# Episode 21/9000, total reward: -48.146, entropy_coef: 0.0098, demands: 1
# Episode 22/9000, total reward: -47.729, entropy_coef: 0.0098, demands: 1
9000, total reward: 94.000, entropy_coef: 0.0010, demands: 2
# Episode 8813/9000, total reward: 94.833, entropy_coef: 0.0010, demands: 3
# Episode 8814/9000, total reward: 77.822, entropy_coef: 0.0010, demands: 4
# Episode 8815/9000, total reward: 91.047, entropy_coef: 0.0010, demands: 6
# Episode 8816/9000, total reward: 76.807, entropy_coef: 0.0010, demands: 6
# Episode 8817/9000, total reward: 94.011, entropy_coef: 0.0010, demands: 1
# Episode 8818/9000, total reward: 93.854, entropy_coef: 0.0010, demands: 3
# Episode 8819/9000, total reward: 91.747, entropy_coef: 0.0010, demands: 2
# Episode 8820/9000, total reward: 95.135, entropy_coef: 0.0010, demands: 4
# Episode 8821/9000, total reward: 87.752, entropy_coef: 0.0010, demands: 2
# Episode 8822/9000, total reward: 86.568, entropy_coef: 0.0010, demands: 2
# Episode 8823/9000, total reward: 92.117, entropy_coef: 0.0010, demands: 6
# Episode 8824/9000, total reward: 87.491, entropy_coef: 0.0010, demands: 1
# Episode 8825/9000, total reward: 92.521, entropy_coef: 0.0010, demands: 4
# Episode 8826/9000, total reward: 85.802, entropy_coef: 0.0010, demands: 4
# Episode 8827/9000, total reward: 94.719, entropy_coef: 0.0010, demands: 5
# Episode 8828/9000, total reward: 92.915, entropy_coef: 0.0010, demands: 5
# Episode 8829/9000, total reward: 89.426, entropy_coef: 0.0010, demands: 3
# Episode 8830/9000, total reward: 92.934, entropy_coef: 0.0010, demands: 5
# Episode 8831/9000, total reward: 82.984, entropy_coef: 0.0010, demands: 4
# Episode 8832/9000, total reward: 93.999, entropy_coef: 0.0010, demands: 2
# Episode 8833/9000, total reward: 94.797, entropy_coef: 0.0010, demands: 2
# Episode 8834/9000, total reward: 94.100, entropy_coef: 0.0010, demands: 4
# Episode 8835/9000, total reward: 91.983, entropy_coef: 0.0010, demands: 3
# Episode 8836/9000, total reward: 95.683, entropy_coef: 0.0010, demands: 2
# Episode 8837/9000, total reward: 94.875, entropy_coef: 0.0010, demands: 4
# Episode 8838/9000, total reward: 95.846, entropy_coef: 0.0010, demands: 4
# Episode 8839/9000, total reward: 90.259, entropy_coef: 0.0010, demands: 4
# Episode 8840/9000, total reward: 94.933, entropy_coef: 0.0010, demands: 6
# Episode 8841/9000, total reward: 93.269, entropy_coef: 0.0010, demands: 1
# Episode 8842/9000, total reward: 93.667, entropy_coef: 0.0010, demands: 6
# Episode 8843/9000, total reward: 90.686, entropy_coef: 0.0010, demands: 3
# Episode 8844/9000, total reward: 94.667, entropy_coef: 0.0010, demands: 1
# Episode 8845/9000, total reward: 94.833, entropy_coef: 0.0010, demands: 5
# Episode 8846/9000, total reward: 88.857, entropy_coef: 0.0010, demands: 2
# Episode 8847/9000, total reward: 95.597, entropy_coef: 0.0010, demands: 6
# Episode 8848/9000, total reward: 84.913, entropy_coef: 0.0010, demands: 3
# Episode 8849/9000, total reward: 84.449, entropy_coef: 0.0010, demands: 2
# Episode 8850/9000, total reward: 87.500, entropy_coef: 0.0010, demands: 4
# Episode 8851/9000, total reward: 83.493, entropy_coef: 0.0010, demands: 5
# Episode 8852/9000, total reward: 95.039, entropy_coef: 0.0010, demands: 5
# Episode 8853/9000, total reward: 88.361, entropy_coef: 0.0010, demands: 6
# Episode 8854/9000, total reward: 89.192, entropy_coef: 0.0010, demands: 5
# Episode 8855/9000, total reward: 85.645, entropy_coef: 0.0010, demands: 3
# Episode 8856/9000, total reward: 93.567, entropy_coef: 0.0010, demands: 1
# Episode 8857/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 1
# Episode 8858/9000, total reward: 92.688, entropy_coef: 0.0010, demands: 4
# Episode 8859/9000, total reward: 94.467, entropy_coef: 0.0010, demands: 4
# Episode 8860/9000, total reward: 93.106, entropy_coef: 0.0010, demands: 6
# Episode 8861/9000, total reward: 87.206, entropy_coef: 0.0010, demands: 5
# Episode 8862/9000, total reward: 70.470, entropy_coef: 0.0010, demands: 4
# Episode 8863/9000, total reward: 91.405, entropy_coef: 0.0010, demands: 5
# Episode 8864/9000, total reward: 82.659, entropy_coef: 0.0010, demands: 2
# Episode 8865/9000, total reward: 94.465, entropy_coef: 0.0010, demands: 6
# Episode 8866/9000, total reward: 94.219, entropy_coef: 0.0010, demands: 6
# Episode 8867/9000, total reward: 79.456, entropy_coef: 0.0010, demands: 4
# Episode 8868/9000, total reward: 94.284, entropy_coef: 0.0010, demands: 6
# Episode 8869/9000, total reward: 92.577, entropy_coef: 0.0010, demands: 1
# Episode 8870/9000, total reward: 84.497, entropy_coef: 0.0010, demands: 5
# Episode 8871/9000, total reward: 92.058, entropy_coef: 0.0010, demands: 2
# Episode 8872/9000, total reward: 95.653, entropy_coef: 0.0010, demands: 2
# Episode 8873/9000, total reward: 94.027, entropy_coef: 0.0010, demands: 1
# Episode 8874/9000, total reward: 90.854, entropy_coef: 0.0010, demands: 2
# Episode 8875/9000, total reward: 91.458, entropy_coef: 0.0010, demands: 4
# Episode 8876/9000, total reward: 94.400, entropy_coef: 0.0010, demands: 6
# Episode 8877/9000, total reward: 85.042, entropy_coef: 0.0010, demands: 2
# Episode 8878/9000, total reward: 89.812, entropy_coef: 0.0010, demands: 3
# Episode 8879/9000, total reward: 88.390, entropy_coef: 0.0010, demands: 3
# Episode 8880/9000, total reward: 95.467, entropy_coef: 0.0010, demands: 6
# Episode 8881/9000, total reward: 89.487, entropy_coef: 0.0010, demands: 1
# Episode 8882/9000, total reward: 94.854, entropy_coef: 0.0010, demands: 1
# Episode 8883/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 6
# Episode 8884/9000, total reward: 76.920, entropy_coef: 0.0010, demands: 6
# Episode 8885/9000, total reward: 91.096, entropy_coef: 0.0010, demands: 1
# Episode 8886/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 4
# Episode 8887/9000, total reward: 87.948, entropy_coef: 0.0010, demands: 6
# Episode 8888/9000, total reward: 92.592, entropy_coef: 0.0010, demands: 6
# Episode 8889/9000, total reward: 85.831, entropy_coef: 0.0010, demands: 2
# Episode 8890/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 5
# Episode 8891/9000, total reward: 86.004, entropy_coef: 0.0010, demands: 3
# Episode 8892/9000, total reward: 94.585, entropy_coef: 0.0010, demands: 2
# Episode 8893/9000, total reward: 94.014, entropy_coef: 0.0010, demands: 3
# Episode 8894/9000, total reward: 88.214, entropy_coef: 0.0010, demands: 5
# Episode 8895/9000, total reward: 89.682, entropy_coef: 0.0010, demands: 1
# Episode 8896/9000, total reward: 76.911, entropy_coef: 0.0010, demands: 3
# Episode 8897/9000, total reward: 92.406, entropy_coef: 0.0010, demands: 3
# Episode 8898/9000, total reward: 94.014, entropy_coef: 0.0010, demands: 6
# Episode 8899/9000, total reward: 86.744, entropy_coef: 0.0010, demands: 4
# Episode 8900/9000, total reward: 91.436, entropy_coef: 0.0010, demands: 5
# Episode 8901/9000, total reward: 92.994, entropy_coef: 0.0010, demands: 3
# Episode 8902/9000, total reward: 93.259, entropy_coef: 0.0010, demands: 5
# Episode 8903/9000, total reward: 89.021, entropy_coef: 0.0010, demands: 3
# Episode 8904/9000, total reward: 94.509, entropy_coef: 0.0010, demands: 6
# Episode 8905/9000, total reward: 80.782, entropy_coef: 0.0010, demands: 6
# Episode 8906/9000, total reward: 76.193, entropy_coef: 0.0010, demands: 3
# Episode 8907/9000, total reward: 90.606, entropy_coef: 0.0010, demands: 2
# Episode 8908/9000, total reward: 93.359, entropy_coef: 0.0010, demands: 3
# Episode 8909/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 2
# Episode 8910/9000, total reward: 95.000, entropy_coef: 0.0010, demands: 5
# Episode 8911/9000, total reward: 92.022, entropy_coef: 0.0010, demands: 5
# Episode 8912/9000, total reward: 90.750, entropy_coef: 0.0010, demands: 5
# Episode 8913/9000, total reward: 91.583, entropy_coef: 0.0010, demands: 4
# Episode 8914/9000, total reward: 91.750, entropy_coef: 0.0010, demands: 1
# Episode 8915/9000, total reward: 94.812, entropy_coef: 0.0010, demands: 1
# Episode 8916/9000, total reward: 79.143, entropy_coef: 0.0010, demands: 3
# Episode 8917/9000, total reward: 89.860, entropy_coef: 0.0010, demands: 2
# Episode 8918/9000, total reward: 88.984, entropy_coef: 0.0010, demands: 5
# Episode 8919/9000, total reward: 94.734, entropy_coef: 0.0010, demands: 5
# Episode 8920/9000, total reward: 90.683, entropy_coef: 0.0010, demands: 5
# Episode 8921/9000, total reward: 85.876, entropy_coef: 0.0010, demands: 5
# Episode 8922/9000, total reward: 89.579, entropy_coef: 0.0010, demands: 3
# Episode 8923/9000, total reward: 93.990, entropy_coef: 0.0010, demands: 6
# Episode 8924/9000, total reward: 87.214, entropy_coef: 0.0010, demands: 4
# Episode 8925/9000, total reward: 89.726, entropy_coef: 0.0010, demands: 2
# Episode 8926/9000, total reward: 94.507, entropy_coef: 0.0010, demands: 1
# Episode 8927/9000, total reward: 93.833, entropy_coef: 0.0010, demands: 1
# Episode 8928/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 5
# Episode 8929/9000, total reward: 90.405, entropy_coef: 0.0010, demands: 1
# Episode 8930/9000, total reward: 93.833, entropy_coef: 0.0010, demands: 1
# Episode 8931/9000, total reward: 91.000, entropy_coef: 0.0010, demands: 4
# Episode 8932/9000, total reward: 89.348, entropy_coef: 0.0010, demands: 5
# Episode 8933/9000, total reward: 93.412, entropy_coef: 0.0010, demands: 2
# Episode 8934/9000, total reward: 94.000, entropy_coef: 0.0010, demands: 6
# Episode 8935/9000, total reward: 88.589, entropy_coef: 0.0010, demands: 4
# Episode 8936/9000, total reward: 92.676, entropy_coef: 0.0010, demands: 6
# Episode 8937/9000, total reward: 74.916, entropy_coef: 0.0010, demands: 3
# Episode 8938/9000, total reward: 94.003, entropy_coef: 0.0010, demands: 5
# Episode 8939/9000, total reward: 94.758, entropy_coef: 0.0010, demands: 3
# Episode 8940/9000, total reward: 90.956, entropy_coef: 0.0010, demands: 1
# Episode 8941/9000, total reward: 90.980, entropy_coef: 0.0010, demands: 4
# Episode 8942/9000, total reward: 89.726, entropy_coef: 0.0010, demands: 6
# Episode 8943/9000, total reward: 89.493, entropy_coef: 0.0010, demands: 1
# Episode 8944/9000, total reward: 94.854, entropy_coef: 0.0010, demands: 5
# Episode 8945/9000, total reward: 89.427, entropy_coef: 0.0010, demands: 2
# Episode 8946/9000, total reward: 85.019, entropy_coef: 0.0010, demands: 3
# Episode 8947/9000, total reward: 91.554, entropy_coef: 0.0010, demands: 1
# Episode 8948/9000, total reward: 94.000, entropy_coef: 0.0010, demands: 2
# Episode 8949/9000, total reward: 89.721, entropy_coef: 0.0010, demands: 3
# Episode 8950/9000, total reward: 93.844, entropy_coef: 0.0010, demands: 1
# Episode 8951/9000, total reward: 91.646, entropy_coef: 0.0010, demands: 1
# Episode 8952/9000, total reward: 94.397, entropy_coef: 0.0010, demands: 1
# Episode 8953/9000, total reward: 82.606, entropy_coef: 0.0010, demands: 6
# Episode 8954/9000, total reward: 93.174, entropy_coef: 0.0010, demands: 5
# Episode 8955/9000, total reward: 87.821, entropy_coef: 0.0010, demands: 3
# Episode 8956/9000, total reward: 84.879, entropy_coef: 0.0010, demands: 4
# Episode 8957/9000, total reward: 90.260, entropy_coef: 0.0010, demands: 1
# Episode 8958/9000, total reward: 94.854, entropy_coef: 0.0010, demands: 4
# Episode 8959/9000, total reward: 90.862, entropy_coef: 0.0010, demands: 1
# Episode 8960/9000, total reward: 94.000, entropy_coef: 0.0010, demands: 4
# Episode 8961/9000, total reward: 89.311, entropy_coef: 0.0010, demands: 3
# Episode 8962/9000, total reward: 92.485, entropy_coef: 0.0010, demands: 5
# Episode 8963/9000, total reward: 90.288, entropy_coef: 0.0010, demands: 4
# Episode 8964/9000, total reward: 74.977, entropy_coef: 0.0010, demands: 1
# Episode 8965/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 1
# Episode 8966/9000, total reward: 93.854, entropy_coef: 0.0010, demands: 1
# Episode 8967/9000, total reward: 95.585, entropy_coef: 0.0010, demands: 2
# Episode 8968/9000, total reward: 87.870, entropy_coef: 0.0010, demands: 6
# Episode 8969/9000, total reward: 93.386, entropy_coef: 0.0010, demands: 2
# Episode 8970/9000, total reward: 85.374, entropy_coef: 0.0010, demands: 3
# Episode 8971/9000, total reward: 95.709, entropy_coef: 0.0010, demands: 6
# Episode 8972/9000, total reward: 86.940, entropy_coef: 0.0010, demands: 3
# Episode 8973/9000, total reward: 79.390, entropy_coef: 0.0010, demands: 3
# Episode 8974/9000, total reward: 94.263, entropy_coef: 0.0010, demands: 6
# Episode 8975/9000, total reward: 85.323, entropy_coef: 0.0010, demands: 4
# Episode 8976/9000, total reward: 91.881, entropy_coef: 0.0010, demands: 3
# Episode 8977/9000, total reward: 93.377, entropy_coef: 0.0010, demands: 6
# Episode 8978/9000, total reward: 81.901, entropy_coef: 0.0010, demands: 2
# Episode 8979/9000, total reward: 88.147, entropy_coef: 0.0010, demands: 5
# Episode 8980/9000, total reward: 90.459, entropy_coef: 0.0010, demands: 2
# Episode 8981/9000, total reward: 92.231, entropy_coef: 0.0010, demands: 1
# Episode 8982/9000, total reward: 94.854, entropy_coef: 0.0010, demands: 2
# Episode 8983/9000, total reward: 95.429, entropy_coef: 0.0010, demands: 2
# Episode 8984/9000, total reward: 91.875, entropy_coef: 0.0010, demands: 2
# Episode 8985/9000, total reward: 96.000, entropy_coef: 0.0010, demands: 1
# Episode 8986/9000, total reward: 95.000, entropy_coef: 0.0010, demands: 2
# Episode 8987/9000, total reward: 86.298, entropy_coef: 0.0010, demands: 3
# Episode 8988/9000, total reward: 95.485, entropy_coef: 0.0010, demands: 2
# Episode 8989/9000, total reward: 94.257, entropy_coef: 0.0010, demands: 5
# Episode 8990/9000, total reward: 95.595, entropy_coef: 0.0010, demands: 4
# Episode 8991/9000, total reward: 88.486, entropy_coef: 0.0010, demands: 1
# Episode 8992/9000, total reward: 83.732, entropy_coef: 0.0010, demands: 4
# Episode 8993/9000, total reward: 91.592, entropy_coef: 0.0010, demands: 4
# Episode 8994/9000, total reward: 94.117, entropy_coef: 0.0010, demands: 6
# Episode 8995/9000, total reward: 95.336, entropy_coef: 0.0010, demands: 4
# Episode 8996/9000, total reward: 89.534, entropy_coef: 0.0010, demands: 4
# Episode 8997/9000, total reward: 94.529, entropy_coef: 0.0010, demands: 5
# Episode 8998/9000, total reward: 80.703, entropy_coef: 0.0010, demands: 5
# Episode 8999/9000, total reward: 85.321, entropy_coef: 0.0010, demands: 6
# Episode 9000/9000, total reward: 84.486, entropy_coef: 0.0010, demands: 1

# %%
# === Plot learning curve with running average ===
window = 30                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=2, label=f"Running Avg (window={window})")
plt.xlabel("Episode")
plt.ylabel("Smoothed Total Reward")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ## Testing the Agent

# %%
def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=50, f_qkp=True):
    agent.model.eval()  # Set network to evaluation mode
    test_rewards = []
    success_counts = 0

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes ---")

    for ep in range(num_test_episodes):
        # Reset environment
        mean_kbps_rand = random.randint(2, 3)
        demands_space = generate_demands(gnodes, syst, mean_kbps=0.1*mean_kbps_rand, amp=0.5, noise_std=0, pattern="sinusoidal")

        MIN_DEMANDS = 1
        MAX_DEMANDS = len(demands_space)
        k = random.randint(MIN_DEMANDS, MAX_DEMANDS)
        demands = random.sample(demands_space, k)
        random.shuffle(demands)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands #generate_demands(gnodes, syst, mean_kbps=1.5, pattern="sinusoidal") # Use unseen noise/pattern
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} # Start with empty pool

        ep_reward = 0
        
        for t in syst.T:
            s_vec = build_state_vector_for_time(state[t], links, t, f_qkp=f_qkp)
            s_tensor = torch.tensor(s_vec, dtype=torch.float32).unsqueeze(0).to(DEVICE)

            with torch.no_grad():
                # Get action deterministically (most likely action, no sampling)
                # Note: You may need a method like agent.get_deterministic_action() 
                # or manually take the argmax/mean of the policy output.
                action_vec, _, _ = agent.select_action(s_vec) 

            # Environment Step (Logic from your training loop)
            # [Insert your constraint check: check_tx, check_rx]
            # [Insert your env step: online_new]
            check_tx, check_rx = 1, 1
            sum_tx, sum_rx = {}, {}
        
            nodes = gnodes + hnodes
            for idx_h, h in enumerate(hnodes):
                sum_tx[idx_h] = sum(action[t][idx_l]
                                    for idx_l, l in enumerate(links)
                                    if  l.n1 == h
                                   )
    
                sum_rx[idx_h] = sum(action[t][idx_l]
                                    for idx_l, l in enumerate(links)
                                    if  l.n2 == h
                                   )
                
                check_tx = check_tx and (sum_tx[idx_h] <= h.N_TX)
                check_rx = check_rx and (sum_rx[idx_h] <= h.N_RX)
    
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, action, t, f_qkp)
            else:
                reward_t = -sum(sum_tx[idx_h] + sum_rx[idx_h] for idx_h, h in enumerate(hnodes)) / len(hnodes) / len(gnodes) / 2 #-10
            
            # Record results
            ep_reward += reward_t

            # Update next state
            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        print(f"Test Episode {ep+1}: Total Reward = {ep_reward:.2f}, demands: {len(demands)}")

    avg_reward = sum(test_rewards) / num_test_episodes
    print(f"--- Evaluation Complete. Average Reward: {avg_reward:.2f} ---")
    return test_rewards

# Run the test
results = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=200, f_qkp=f_qkp)
# Out:
# --- Starting Evaluation for 200 Episodes ---
# Test Episode 1: Total Reward = 92.83, demands: 4
# Test Episode 2: Total Reward = 92.87, demands: 6
# Test Episode 3: Total Reward = 92.96, demands: 2
# Test Episode 4: Total Reward = 93.22, demands: 2
# Test Episode 5: Total Reward = 90.62, demands: 4
# Test Episode 6: Total Reward = 84.49, demands: 6
# Test Episode 7: Total Reward = 92.18, demands: 2
# Test Episode 8: Total Reward = 91.01, demands: 4
# Test Episode 9: Total Reward = 92.87, demands: 6
# Test Episode 10: Total Reward = 94.09, demands: 3
# Test Episode 11: Total Reward = 93.72, demands: 3
# Test Episode 12: Total Reward = 91.73, demands: 3
# Test Episode 13: Total Reward = 92.41, demands: 5
# Test Episode 14: Total Reward = 92.87, demands: 6
# Test Episode 15: Total Reward = 91.17, demands: 3
# Test Episode 16: Total Reward = 88.79, demands: 2
# Test Episode 17: Total Reward = 88.00, demands: 1
# Test Episode 18: Total Reward = 93.55, demands: 5
# Test Episode 19: Total Reward = 92.96, demands: 2
# Test Episode 20: Total Reward = 91.17, demands: 3
# Test Episode 21: Total Reward = 88.00, demands: 1
# Test Episode 22: Total Reward = 84.49, demands: 6
