# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python
# Traceback (most recent call last):
#
#   File /opt/miniconda3/envs/py310/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from libraries import *
#
#   File ~/HAP-QKD/libraries.py:59
#     from plot   import *
#
#   File ~/HAP-QKD/plot.py:626
#     plt.savefig("hap_qkd_trajectory_3d.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True"
#                ^
# SyntaxError: '(' was never closed

# %%
init_setup_real_skr_plot()

# %%
# plot_loss_distance(1,0,0,0)

# %%
# plot_skr_distance()

# %%
# plot_skr()

# %%
# plot_skr_eta_stratotegic_real()
