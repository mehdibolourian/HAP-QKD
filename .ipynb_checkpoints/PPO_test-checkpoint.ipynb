# %%
from libraries import *

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2739131
# Academic license - for non-commercial use only - expires 2026-11-14
# Warning: Gurobi version mismatch between Python 12.0.2 and C library 12.0.3

# %%
gnodes, hnodes, links, demands = init_setup_real()
# Out:
#      Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0       0.0     279.000000     49.000000  25000.00000
# 1    3600.0     278.974006     49.042329  23672.57558
# 4    7200.0     278.932833     49.055108  22986.64633
# 7   10800.0     278.900893     49.018890  19378.08451
# 10  14400.0     278.989935     48.980466  20387.52864
# 13  18000.0     279.006678     48.992932  21378.46182
# 16  21600.0     279.038680     49.008456  21722.88519
# 19  25200.0     279.061682     49.024487  23068.06755
# 22  28800.0     279.067620     49.034208  22980.28988
# 25  32400.0     279.080779     49.013625  23209.52264
# 28  36000.0     279.075842     48.996233  23206.76795
# 31  39600.0     279.055069     48.999030  23206.48967
# 34  43200.0     279.049362     48.977709  23429.46557
# 37  46800.0     279.054583     49.001266  22740.73417
# 40  50400.0     278.985247     48.953397  21049.70677
# 43  54000.0     278.919923     48.953306  20474.85927
# 46  57600.0     278.939021     48.977959  19860.05593
# 49  61200.0     278.994659     48.965139  19574.35484
# 52  64800.0     279.043770     48.980250  19784.07311
# 55  68400.0     279.089595     48.954722  18975.42547
# 58  72000.0     279.162255     49.008611  19329.06589
# 61  75600.0     279.282568     49.086498  19451.14069
# 64  79200.0     279.469930     49.125324  21958.28937
# 67  82800.0     279.593425     49.128661  24030.70810
# 70  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=23 (24 time steps)
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval [0, 24) fully covered in checkpoint.

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# %%
# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.2
LR = 3e-4
EPOCHS = 4
BATCH_SIZE = 64
ENTROPY_COEF_INITIAL = 0.05         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.995               # >>> CHANGE
VALUE_COEF = 0.5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

print(f"len(gnodes): {len(gnodes)}")

def build_state_vector_for_time(state_t, links, t, n_nodes=len(gnodes), normalize=True):
    """
    Build state vector for the QKD environment.

    state_t["a"]: dict or list of QKP (stored key bits) for each link.
    state_t["demands"]: list of demand objects with attributes (K_REQ, n1, n2).

    Output vector structure:
        [ QKP_link0, ..., QKP_linkL-1,
          onehot_src_demand0..., onehot_dst_demand0..., KREQ_0,
          onehot_src_demand1..., onehot_dst_demand1..., KREQ_1,
          ... ]

    Args:
        state_t: dict for time t
        links: list of link objects (or identifiers)
        n_nodes: total number of GS/HAP nodes (used for one-hot encoding)
        normalize: normalize QKP and KREQ values to [0, 1] range if True
    """
    # --- QKP per link ---
    a_vec = np.array(
        [state_t.get("a", {}).get(l, 0.0) for l in range(len(links))],
        dtype=np.float32
    )

    # normalize QKP values if desired
    if normalize and len(a_vec) > 0:
        max_qkp = np.max(a_vec) if np.max(a_vec) > 0 else 1.0
        a_vec = a_vec / max_qkp

    # --- Encode demands ---
    d_vec = []
    for d in state_t.get("demands", []):
        # normalize K_REQ
        kreq = float(d.K_REQ[t])
        if normalize and kreq > 0:
            kreq = kreq / (kreq + 1e-6)  # simple scaling to (0,1)
        # one-hot encode endpoints if n_nodes provided
        if n_nodes is not None:
            onehot_src = np.zeros(n_nodes, dtype=np.float32)
            onehot_dst = np.zeros(n_nodes, dtype=np.float32)
            if 0 <= gnodes.index(d.n1) < n_nodes:
                onehot_src[gnodes.index(d.n1)] = 1.0
            if 0 <= gnodes.index(d.n2) < n_nodes:
                onehot_dst[gnodes.index(d.n2)] = 1.0
            d_vec.extend(onehot_src.tolist() + onehot_dst.tolist() + [kreq])
        else:
            # fallback to simpler encoding if node info omitted
            d_vec.append(kreq)

    # --- Concatenate ---
    state_vector = np.concatenate([a_vec, np.array(d_vec, dtype=np.float32)])
    return state_vector

# >>> ADD utility to build binary mask of feasible actions
def build_action_mask(links, demands, gnodes, hnodes, state_t):
    mask = np.ones(n_links * n_demands, dtype=np.float32)

    # try to activate each link-demand action hypothetically and see if feasible
    for idx_l, l in enumerate(links):
        for idx_d, d in enumerate(demands):
            flat_idx = idx_l * n_demands + idx_d

            # count TX/RX usage if this action is taken
            tx_ok = state_t["a"].get(idx_l, 0) <= l.n1.N_TX - 1
            rx_ok = state_t["a"].get(idx_l, 0) <= l.n2.N_RX - 1

            if not (tx_ok and rx_ok):
                mask[flat_idx] = 0.0
    return mask

# ---------- Actor-Critic network for multi-binary action ----------
class ActorCriticBinary(nn.Module):
    def __init__(self, state_dim, action_dim, hidden=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.ReLU()
        )
        # outputs logits for Bernoulli per action dimension
        self.logit_head = nn.Linear(hidden, action_dim)
        # critic outputs a scalar value
        self.critic = nn.Sequential(
            nn.Linear(state_dim, hidden//2),
            nn.ReLU(),
            nn.Linear(hidden//2, 1)
        )

    def forward(self, state):
        """
        state: tensor of shape [batch, state_dim]
        returns:
            logits: [batch, action_dim]
            value: [batch, 1]
        """
        h = self.net(state)
        logits = self.logit_head(h)
        value = self.critic(state)
        return logits, value.squeeze(-1)

# ---------- PPO Agent for binary actions ----------
class PPOBinaryAgent:
    def __init__(self, state_dim, action_dim, lr=LR):
        self.model = ActorCriticBinary(state_dim, action_dim).to(DEVICE)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.action_dim = action_dim

    def select_action(self, state_vec, mask=None):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        logits, value = self.model(s)  # [1, action_dim], [1]

        # >>> CHANGE — apply action mask BEFORE sampling
        if mask is not None:
            # mask=1 allowed, mask=0 blocked
            mask = torch.tensor(mask, dtype=torch.float32, device=DEVICE)
            blocked = (mask == 0)
            logits = logits.masked_fill(blocked, -1e9)

        probs = torch.sigmoid(logits)
        m = torch.distributions.Bernoulli(probs)
        action = m.sample()
        logp = m.log_prob(action).sum(dim=-1)

        return action.squeeze(0).cpu().numpy().astype(int), logp.squeeze(0).detach(), value.squeeze(0).detach()

    def compute_gae(self, rewards, values, dones, gamma=GAMMA, lam=GAE_LAMBDA):
        # rewards: list length T
        # values: tensor shape [T+1] containing state values; values[-1] is bootstrap for final
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            delta = rewards[t] + gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + gamma * lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
        returns = adv + values[:-1]
        return adv, returns

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef):  # >>> CHANGE - new param
        """
        states: tensor [N, state_dim]
        actions: tensor [N, action_dim] (0/1)
        old_logps: tensor [N] (scalar log prob of full action vector)
        returns: tensor [N]
        advantages: tensor [N]
        """
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        N = states.shape[0]
        idxs = np.arange(N)
        for _ in range(EPOCHS):
            np.random.shuffle(idxs)
            for start in range(0, N, BATCH_SIZE):
                batch_idx = idxs[start:start + BATCH_SIZE]
                b_states = states[batch_idx].to(DEVICE)
                b_actions = actions[batch_idx].to(DEVICE).float()
                b_old_logps = old_logps[batch_idx].to(DEVICE)
                b_returns = returns[batch_idx].to(DEVICE)
                b_adv = advantages[batch_idx].to(DEVICE)

                logits, values = self.model(b_states)
                probs = torch.sigmoid(logits)
                dist = torch.distributions.Bernoulli(probs)
                new_logp = dist.log_prob(b_actions).sum(dim=-1)
                entropy = dist.entropy().sum(dim=-1).mean()

                ratio = torch.exp(new_logp - b_old_logps)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - CLIP, 1.0 + CLIP) * b_adv
                actor_loss = -torch.min(surr1, surr2).mean()
                critic_loss = F.mse_loss(values, b_returns)

                loss = actor_loss + VALUE_COEF * critic_loss - entropy_coef * entropy  # >>> CHANGE

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
# Out:
# len(gnodes): 2

# %%
# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T
action_dim = n_links * n_demands

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(state[0], links, 0)
state_dim = len(state_vector_example)

agent = PPOBinaryAgent(state_dim, action_dim, lr=LR)

# Training hyperparams
num_episodes = 2000
episode_len = len(syst.T)

# Track total rewards per episode
episode_rewards = []

solution = {"a": state[0]["a"].copy()}

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]
    state[0]["demands"] = demands.copy()
    state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf = []
    actions_buf = []
    logps_buf = []
    rewards_buf = []
    dones_buf = []
    values_buf = []

    total_reward = 0.0

    for t in syst.T:
        # >>> NEW — build action mask before selecting action
        mask = build_action_mask(links, demands, gnodes, hnodes, state[t])
        s_vec = build_state_vector_for_time(state[t], links, t)

        action_vec, logp, value = agent.select_action(s_vec, mask=mask)   # >>> CHANGE

        # convert flat action vector to dictionary
        action[t] = {}
        for idx_l in range(n_links):
            for idx_d in range(len(state[t]["demands"])):
                flat_idx = idx_l * n_demands + idx_d
                action[t][(idx_l, idx_d)] = int(action_vec[flat_idx])

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes
        for idx_n, n in enumerate(nodes):
            sum_tx[idx_n] = sum(action[t][(idx_l, idx_d)]
                                for idx_l, l in enumerate(links)
                                for idx_d, d in enumerate(demands)
                                if  l.n1 == n
                               )

            sum_rx[idx_n] = sum(action[t][(idx_l, idx_d)]
                                for idx_l, l in enumerate(links)
                                for idx_d, d in enumerate(demands)
                                if  l.n1 == n
                               )
            
            check_tx = check_tx and (sum_tx[idx_n] <= n.N_TX)
            check_rx = check_rx and (sum_rx[idx_n] <= n.N_RX)

            # if not check_tx or not check_rx:
            #     # print("Violated maximum RX/TX constraints!")
            #     break

        if check_tx and check_rx:
            solution, reward_t = online_new(gnodes, hnodes, links, state, action, t, 1)
        else:
            reward_t = -sum(sum_tx[idx_n] + sum_rx[idx_n] for idx_n, n in enumerate(nodes)) / len(nodes) / 2 #-10

        reward[t] = reward_t
        total_reward += reward_t

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        actions_buf.append(torch.tensor(action_vec, dtype=torch.float32))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))

        # step to next state
        if t + 1 < episode_len:
            if check_tx and check_rx:
                state[t+1]["a"] = solution["a"]
            else:
                state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(state[-1], links, t)
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor, final_value.view(1)])   # shape [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}")

# === Plot learning curve ===
plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/1000, total reward: 73.000, entropy_coef: 0.0498
# Episode 2/1000, total reward: 73.400, entropy_coef: 0.0495
# Episode 3/1000, total reward: -4.400, entropy_coef: 0.0493
# Episode 4/1000, total reward: 21.400, entropy_coef: 0.0490
# Episode 5/1000, total reward: -28.000, entropy_coef: 0.0488
# Episode 6/1000, total reward: 40.200, entropy_coef: 0.0485
# Episode 7/1000, total reward: -27.800, entropy_coef: 0.0483
# Episode 8/1000, total reward: 98.400, entropy_coef: 0.0480
# Episode 9/1000, total reward: 32.000, entropy_coef: 0.0478
# Episode 10/1000, total reward: -5.000, entropy_coef: 0.0476
# Episode 11/1000, total reward: 86.400, entropy_coef: 0.0473
# Episode 12/1000, total reward: 64.800, entropy_coef: 0.0471
# Episode 13/1000, total reward: -26.800, entropy_coef: 0.0468
# Episode 14/1000, total reward: 51.400, entropy_coef: 0.0466
# Episode 15/1000, total reward: 18.000, entropy_coef: 0.0464
# Episode 16/1000, total reward: 29.800, entropy_coef: 0.0461
# Episode 17/1000, total reward: 97.200, entropy_coef: 0.0459
# Episode 18/1000, total reward: 97.000, entropy_coef: 0.0457
# Episode 19/1000, total reward: -24.800, entropy_coef: 0.0455
# Episode 20/1000, total reward: 53.000, entropy_coef: 0.0452
# Episode 21/1000, total reward: 41.600, entropy_coef: 0.0450
# Episode 22/1000, total reward: 64.200, entropy_coef: 0.0448
# Episode 23/1000, total reward: 1.000, entropy_coef: 0.0446
# Episode 24/1000, total reward: 50.000, entropy_coef: 0.0443
# Episode 25/1000, total reward: 64.400, entropy_coef: 0.0441
# Episode 26/1000, total reward: 86.400, entropy_coef: 0.0439
# Episode 27/1000, total reward: -15.200, entropy_coef: 0.0437
# Episode 28/1000, total reward: 73.600, entropy_coef: 0.0435
# Episode 29/1000, total reward: 85.400, entropy_coef: 0.0432
# Episode 30/1000, total reward: 53.600, entropy_coef: 0.0430
# Episode 31/1000, total reward: 20.200, entropy_coef: 0.0428
# Episode 32/1000, total reward: 74.200, entropy_coef: 0.0426
# Episode 33/1000, total reward: 76.000, entropy_coef: 0.0424
# Episode 34/1000, total reward: 87.600, entropy_coef: 0.0422
# Episode 35/1000, total reward: -27.600, entropy_coef: 0.0420
# Episode 36/1000, total reward: 64.600, entropy_coef: 0.0417
# Episode 37/1000, total reward: 131.400, entropy_coef: 0.0415
# Episode 38/1000, total reward: 119.800, entropy_coef: 0.0413
# Episode 39/1000, total reward: 42.000, entropy_coef: 0.0411
# Episode 40/1000, total reward: 141.400, entropy_coef: 0.0409
# Episode 41/1000, total reward: 130.400, entropy_coef: 0.0407
# Episode 42/1000, total reward: 76.600, entropy_coef: 0.0405
# Episode 43/1000, total reward: 41.800, entropy_coef: 0.0403
# Episode 44/1000, total reward: 87.200, entropy_coef: 0.0401
# Episode 45/1000, total reward: 98.400, entropy_coef: 0.0399
# Episode 46/1000, total reward: 109.400, entropy_coef: 0.0397
# Episode 47/1000, total reward: 108.000, entropy_coef: 0.0395
# Episode 48/1000, total reward: 123.000, entropy_coef: 0.0393
# Episode 49/1000, total reward: 86.600, entropy_coef: 0.0391
# Episode 50/1000, total reward: 174.800, entropy_coef: 0.0389
# Episode 51/1000, total reward: 98.400, entropy_coef: 0.0387
# Episode 52/1000, total reward: 110.400, entropy_coef: 0.0385
# Episode 53/1000, total reward: 163.600, entropy_coef: 0.0383
# Episode 54/1000, total reward: 163.400, entropy_coef: 0.0381
# Episode 55/1000, total reward: 108.800, entropy_coef: 0.0380
# Episode 56/1000, total reward: 131.800, entropy_coef: 0.0378
# Episode 57/1000, total reward: 174.000, entropy_coef: 0.0376
# Episode 58/1000, total reward: 112.000, entropy_coef: 0.0374
# Episode 59/1000, total reward: 229.000, entropy_coef: 0.0372
# Episode 60/1000, total reward: 176.200, entropy_coef: 0.0370
# Episode 61/1000, total reward: 197.400, entropy_coef: 0.0368
# Episode 62/1000, total reward: 154.000, entropy_coef: 0.0366
# Episode 63/1000, total reward: 152.600, entropy_coef: 0.0365
# Episode 64/1000, total reward: 195.800, entropy_coef: 0.0363
# Episode 65/1000, total reward: 185.200, entropy_coef: 0.0361
# Episode 66/1000, total reward: 218.200, entropy_coef: 0.0359
# Episode 67/1000, total reward: 44.400, entropy_coef: 0.0357
# Episode 68/1000, total reward: 197.400, entropy_coef: 0.0356
# Episode 69/1000, total reward: 142.400, entropy_coef: 0.0354
# Episode 70/1000, total reward: 186.000, entropy_coef: 0.0352
# Episode 71/1000, total reward: 122.200, entropy_coef: 0.0350
# Episode 72/1000, total reward: 185.000, entropy_coef: 0.0349
# Episode 73/1000, total reward: 240.000, entropy_coef: 0.0347
# Episode 74/1000, total reward: 196.600, entropy_coef: 0.0345
# Episode 75/1000, total reward: 185.000, entropy_coef: 0.0343
# Episode 76/1000, total reward: 185.400, entropy_coef: 0.0342
# Episode 77/1000, total reward: 185.000, entropy_coef: 0.0340
# Episode 78/1000, total reward: 218.400, entropy_coef: 0.0338
# Episode 79/1000, total reward: 174.000, entropy_coef: 0.0337
# Episode 80/1000, total reward: 185.000, entropy_coef: 0.0335
# Episode 81/1000, total reward: 229.000, entropy_coef: 0.0333
# Episode 82/1000, total reward: 196.000, entropy_coef: 0.0331
# Episode 83/1000, total reward: 218.000, entropy_coef: 0.0330
# Episode 84/1000, total reward: 196.600, entropy_coef: 0.0328
# Episode 85/1000, total reward: 185.600, entropy_coef: 0.0327
# Episode 86/1000, total reward: 163.200, entropy_coef: 0.0325
# Episode 87/1000, total reward: 119.000, entropy_coef: 0.0323
# Episode 88/1000, total reward: 196.000, entropy_coef: 0.0322
# Episode 89/1000, total reward: 163.000, entropy_coef: 0.0320
# Episode 90/1000, total reward: 130.600, entropy_coef: 0.0318
# Episode 91/1000, total reward: 185.000, entropy_coef: 0.0317
# Episode 92/1000, total reward: 163.000, entropy_coef: 0.0315
# Episode 93/1000, total reward: 185.000, entropy_coef: 0.0314
# Episode 94/1000, total reward: 54.200, entropy_coef: 0.0312
# Episode 95/1000, total reward: 86.000, entropy_coef: 0.0311
# Episode 96/1000, total reward: 207.000, entropy_coef: 0.0309
# Episode 97/1000, total reward: 218.000, entropy_coef: 0.0307
# Episode 98/1000, total reward: 174.000, entropy_coef: 0.0306
# Episode 99/1000, total reward: 218.600, entropy_coef: 0.0304
# Episode 100/1000, total reward: 108.800, entropy_coef: 0.0303
# Episode 101/1000, total reward: 218.000, entropy_coef: 0.0301
# Episode 102/1000, total reward: 229.000, entropy_coef: 0.0300
# Episode 103/1000, total reward: 196.400, entropy_coef: 0.0298
# Episode 104/1000, total reward: 119.000, entropy_coef: 0.0297
# Episode 105/1000, total reward: 240.000, entropy_coef: 0.0295
# Episode 106/1000, total reward: 152.600, entropy_coef: 0.0294
# Episode 107/1000, total reward: 185.200, entropy_coef: 0.0292
# Episode 108/1000, total reward: 164.000, entropy_coef: 0.0291
# Episode 109/1000, total reward: 197.000, entropy_coef: 0.0290
# Episode 110/1000, total reward: 240.000, entropy_coef: 0.0288
# Episode 111/1000, total reward: 229.000, entropy_coef: 0.0287
# Episode 112/1000, total reward: 218.600, entropy_coef: 0.0285
# Episode 113/1000, total reward: 218.000, entropy_coef: 0.0284
# Episode 114/1000, total reward: 218.400, entropy_coef: 0.0282
# Episode 115/1000, total reward: 218.000, entropy_coef: 0.0281
# Episode 116/1000, total reward: 207.000, entropy_coef: 0.0280
# Episode 117/1000, total reward: 229.000, entropy_coef: 0.0278
# Episode 118/1000, total reward: 54.000, entropy_coef: 0.0277
# Episode 119/1000, total reward: 207.000, entropy_coef: 0.0275
# Episode 120/1000, total reward: -23.000, entropy_coef: 0.0274
# Episode 121/1000, total reward: 163.000, entropy_coef: 0.0273
# Episode 122/1000, total reward: 163.600, entropy_coef: 0.0271
# Episode 123/1000, total reward: 75.000, entropy_coef: 0.0270
# Episode 124/1000, total reward: 185.000, entropy_coef: 0.0269
# Episode 125/1000, total reward: 229.000, entropy_coef: 0.0267
# Episode 126/1000, total reward: 141.000, entropy_coef: 0.0266
# Episode 127/1000, total reward: 141.000, entropy_coef: 0.0265
# Episode 128/1000, total reward: 229.000, entropy_coef: 0.0263
# Episode 129/1000, total reward: 229.000, entropy_coef: 0.0262
# Episode 130/1000, total reward: 207.600, entropy_coef: 0.0261
# Episode 131/1000, total reward: 119.000, entropy_coef: 0.0259
# Episode 132/1000, total reward: 20.600, entropy_coef: 0.0258
# Episode 133/1000, total reward: -23.400, entropy_coef: 0.0257
# Episode 134/1000, total reward: 196.000, entropy_coef: 0.0255
# Episode 135/1000, total reward: 218.000, entropy_coef: 0.0254
# Episode 136/1000, total reward: 218.000, entropy_coef: 0.0253
# Episode 137/1000, total reward: 229.000, entropy_coef: 0.0252
# Episode 138/1000, total reward: 229.000, entropy_coef: 0.0250
# Episode 139/1000, total reward: 174.000, entropy_coef: 0.0249
# Episode 140/1000, total reward: 229.000, entropy_coef: 0.0248
# Episode 141/1000, total reward: 229.000, entropy_coef: 0.0247
# Episode 142/1000, total reward: 174.600, entropy_coef: 0.0245
# Episode 143/1000, total reward: 196.000, entropy_coef: 0.0244
# Episode 144/1000, total reward: 229.000, entropy_coef: 0.0243
# Episode 145/1000, total reward: 229.000, entropy_coef: 0.0242
# Episode 146/1000, total reward: 218.000, entropy_coef: 0.0241
# Episode 147/1000, total reward: 207.000, entropy_coef: 0.0239
# Episode 148/1000, total reward: 218.000, entropy_coef: 0.0238
# Episode 149/1000, total reward: 130.000, entropy_coef: 0.0237
# Episode 150/1000, total reward: 163.600, entropy_coef: 0.0236
# Episode 151/1000, total reward: 229.000, entropy_coef: 0.0235
# Episode 152/1000, total reward: 119.600, entropy_coef: 0.0233
# Episode 153/1000, total reward: 163.000, entropy_coef: 0.0232
# Episode 154/1000, total reward: 196.000, entropy_coef: 0.0231
# Episode 155/1000, total reward: 196.400, entropy_coef: 0.0230
# Episode 156/1000, total reward: 108.000, entropy_coef: 0.0229
# Episode 157/1000, total reward: -24.000, entropy_coef: 0.0228
# Episode 158/1000, total reward: 174.000, entropy_coef: 0.0226
# Episode 159/1000, total reward: 229.000, entropy_coef: 0.0225
# Episode 160/1000, total reward: 152.000, entropy_coef: 0.0224
# Episode 161/1000, total reward: 229.000, entropy_coef: 0.0223
# Episode 162/1000, total reward: 43.200, entropy_coef: 0.0222
# Episode 163/1000, total reward: 163.000, entropy_coef: 0.0221
# Episode 164/1000, total reward: 174.000, entropy_coef: 0.0220
# Episode 165/1000, total reward: 207.000, entropy_coef: 0.0219
# Episode 166/1000, total reward: 75.200, entropy_coef: 0.0218
# Episode 167/1000, total reward: 207.000, entropy_coef: 0.0216
# Episode 168/1000, total reward: 185.800, entropy_coef: 0.0215
# Episode 169/1000, total reward: 240.000, entropy_coef: 0.0214
# Episode 170/1000, total reward: 174.000, entropy_coef: 0.0213
# Episode 171/1000, total reward: 108.400, entropy_coef: 0.0212
# Episode 172/1000, total reward: 196.600, entropy_coef: 0.0211
# Episode 173/1000, total reward: 218.000, entropy_coef: 0.0210
# Episode 174/1000, total reward: 163.000, entropy_coef: 0.0209
# Episode 175/1000, total reward: 108.600, entropy_coef: 0.0208
# Episode 176/1000, total reward: 185.000, entropy_coef: 0.0207
# Episode 177/1000, total reward: 218.400, entropy_coef: 0.0206
# Episode 178/1000, total reward: 175.000, entropy_coef: 0.0205
# Episode 179/1000, total reward: 185.000, entropy_coef: 0.0204
# Episode 180/1000, total reward: 109.000, entropy_coef: 0.0203
# Episode 181/1000, total reward: 229.000, entropy_coef: 0.0202
# Episode 182/1000, total reward: 207.600, entropy_coef: 0.0201
# Episode 183/1000, total reward: 196.000, entropy_coef: 0.0200
# Episode 184/1000, total reward: 76.600, entropy_coef: 0.0199
# Episode 185/1000, total reward: 207.000, entropy_coef: 0.0198
# Episode 186/1000, total reward: 207.000, entropy_coef: 0.0197
# Episode 187/1000, total reward: 185.400, entropy_coef: 0.0196
# Episode 188/1000, total reward: 240.000, entropy_coef: 0.0195
# Episode 189/1000, total reward: 175.400, entropy_coef: 0.0194
# Episode 190/1000, total reward: 229.000, entropy_coef: 0.0193
# Episode 191/1000, total reward: 229.200, entropy_coef: 0.0192
# Episode 192/1000, total reward: 185.200, entropy_coef: 0.0191
# Episode 193/1000, total reward: 206.800, entropy_coef: 0.0190
# Episode 194/1000, total reward: 142.000, entropy_coef: 0.0189
# Episode 195/1000, total reward: 218.400, entropy_coef: 0.0188
# Episode 196/1000, total reward: 218.000, entropy_coef: 0.0187
# Episode 197/1000, total reward: 229.000, entropy_coef: 0.0186
# Episode 198/1000, total reward: 218.000, entropy_coef: 0.0185
# Episode 199/1000, total reward: 229.000, entropy_coef: 0.0184
# Episode 200/1000, total reward: 229.000, entropy_coef: 0.0183
# Episode 201/1000, total reward: 152.800, entropy_coef: 0.0183
# Episode 202/1000, total reward: 152.200, entropy_coef: 0.0182
# Episode 203/1000, total reward: 196.000, entropy_coef: 0.0181
# Episode 204/1000, total reward: 229.000, entropy_coef: 0.0180
# Episode 205/1000, total reward: 185.000, entropy_coef: 0.0179
# Episode 206/1000, total reward: 229.000, entropy_coef: 0.0178
# Episode 207/1000, total reward: 240.000, entropy_coef: 0.0177
# Episode 208/1000, total reward: 152.000, entropy_coef: 0.0176
# Episode 209/1000, total reward: 240.000, entropy_coef: 0.0175
# Episode 210/1000, total reward: 97.400, entropy_coef: 0.0175
# Episode 211/1000, total reward: 130.400, entropy_coef: 0.0174
# Episode 212/1000, total reward: 174.757, entropy_coef: 0.0173
# Episode 213/1000, total reward: 174.757, entropy_coef: 0.0172
# Episode 214/1000, total reward: 152.600, entropy_coef: 0.0171
# Episode 215/1000, total reward: 196.200, entropy_coef: 0.0170
# Episode 216/1000, total reward: 152.400, entropy_coef: 0.0169
# Episode 217/1000, total reward: 163.000, entropy_coef: 0.0168
# Episode 218/1000, total reward: 218.200, entropy_coef: 0.0168
# Episode 219/1000, total reward: 218.000, entropy_coef: 0.0167
# Episode 220/1000, total reward: 218.000, entropy_coef: 0.0166
# Episode 221/1000, total reward: 229.000, entropy_coef: 0.0165
# Episode 222/1000, total reward: 196.600, entropy_coef: 0.0164
# Episode 223/1000, total reward: 218.000, entropy_coef: 0.0163
# Episode 224/1000, total reward: 218.000, entropy_coef: 0.0163
# Episode 225/1000, total reward: 240.000, entropy_coef: 0.0162
# Episode 226/1000, total reward: 218.600, entropy_coef: 0.0161
# Episode 227/1000, total reward: 154.400, entropy_coef: 0.0160
# Episode 228/1000, total reward: 186.400, entropy_coef: 0.0159
# Episode 229/1000, total reward: 208.000, entropy_coef: 0.0159
# Episode 230/1000, total reward: 218.400, entropy_coef: 0.0158
# Episode 231/1000, total reward: 185.600, entropy_coef: 0.0157
# Episode 232/1000, total reward: 186.200, entropy_coef: 0.0156
# Episode 233/1000, total reward: 164.000, entropy_coef: 0.0156
# Episode 234/1000, total reward: 240.000, entropy_coef: 0.0155
# Episode 235/1000, total reward: 197.200, entropy_coef: 0.0154
# Episode 236/1000, total reward: 174.600, entropy_coef: 0.0153
# Episode 237/1000, total reward: 196.600, entropy_coef: 0.0152
# Episode 238/1000, total reward: 196.200, entropy_coef: 0.0152
# Episode 239/1000, total reward: 229.400, entropy_coef: 0.0151
# Episode 240/1000, total reward: 207.600, entropy_coef: 0.0150
# Episode 241/1000, total reward: 174.800, entropy_coef: 0.0149
# Episode 242/1000, total reward: 153.800, entropy_coef: 0.0149
# Episode 243/1000, total reward: 218.000, entropy_coef: 0.0148
# Episode 244/1000, total reward: 163.400, entropy_coef: 0.0147
# Episode 245/1000, total reward: 240.000, entropy_coef: 0.0146
# Episode 246/1000, total reward: 240.000, entropy_coef: 0.0146
# Episode 247/1000, total reward: 152.600, entropy_coef: 0.0145
# Episode 248/1000, total reward: 207.000, entropy_coef: 0.0144
# Episode 249/1000, total reward: 229.600, entropy_coef: 0.0144
# Episode 250/1000, total reward: 196.000, entropy_coef: 0.0143
# Episode 251/1000, total reward: 229.000, entropy_coef: 0.0142
# Episode 252/1000, total reward: 207.000, entropy_coef: 0.0141
# Episode 253/1000, total reward: 75.400, entropy_coef: 0.0141
# Episode 254/1000, total reward: 174.600, entropy_coef: 0.0140
# Episode 255/1000, total reward: 98.000, entropy_coef: 0.0139
# Episode 256/1000, total reward: 207.400, entropy_coef: 0.0139
# Episode 257/1000, total reward: 208.600, entropy_coef: 0.0138
# Episode 258/1000, total reward: 130.400, entropy_coef: 0.0137
# Episode 259/1000, total reward: 185.000, entropy_coef: 0.0137
# Episode 260/1000, total reward: 207.000, entropy_coef: 0.0136
# Episode 261/1000, total reward: 174.000, entropy_coef: 0.0135
# Episode 262/1000, total reward: 152.600, entropy_coef: 0.0134
# Episode 263/1000, total reward: 207.200, entropy_coef: 0.0134
# Episode 264/1000, total reward: 218.000, entropy_coef: 0.0133
# Episode 265/1000, total reward: 240.000, entropy_coef: 0.0132
# Episode 266/1000, total reward: 240.000, entropy_coef: 0.0132
# Episode 267/1000, total reward: 218.000, entropy_coef: 0.0131
# Episode 268/1000, total reward: 196.000, entropy_coef: 0.0130
# Episode 269/1000, total reward: 229.200, entropy_coef: 0.0130
# Episode 270/1000, total reward: 196.600, entropy_coef: 0.0129
# Episode 271/1000, total reward: 119.600, entropy_coef: 0.0129
# Episode 272/1000, total reward: 207.200, entropy_coef: 0.0128
# Episode 273/1000, total reward: 229.000, entropy_coef: 0.0127
# Episode 274/1000, total reward: 163.600, entropy_coef: 0.0127
# Episode 275/1000, total reward: 196.000, entropy_coef: 0.0126
# Episode 276/1000, total reward: 229.000, entropy_coef: 0.0125
# Episode 277/1000, total reward: 163.000, entropy_coef: 0.0125
# Episode 278/1000, total reward: 163.600, entropy_coef: 0.0124
# Episode 279/1000, total reward: 229.000, entropy_coef: 0.0123
# Episode 280/1000, total reward: 218.000, entropy_coef: 0.0123
# Episode 281/1000, total reward: 174.000, entropy_coef: 0.0122
# Episode 282/1000, total reward: 229.000, entropy_coef: 0.0122
# Episode 283/1000, total reward: 207.800, entropy_coef: 0.0121
# Episode 284/1000, total reward: 196.400, entropy_coef: 0.0120
# Episode 285/1000, total reward: 218.000, entropy_coef: 0.0120
# Episode 286/1000, total reward: 240.000, entropy_coef: 0.0119
# Episode 287/1000, total reward: 153.600, entropy_coef: 0.0119
# Episode 288/1000, total reward: 185.000, entropy_coef: 0.0118
# Episode 289/1000, total reward: 163.400, entropy_coef: 0.0117
# Episode 290/1000, total reward: 240.000, entropy_coef: 0.0117
# Episode 291/1000, total reward: 141.400, entropy_coef: 0.0116
# Episode 292/1000, total reward: 185.800, entropy_coef: 0.0116
# Episode 293/1000, total reward: 218.000, entropy_coef: 0.0115
# Episode 294/1000, total reward: 218.000, entropy_coef: 0.0115
# Episode 295/1000, total reward: 152.000, entropy_coef: 0.0114
# Episode 296/1000, total reward: 152.400, entropy_coef: 0.0113
# Episode 297/1000, total reward: 174.000, entropy_coef: 0.0113
# Episode 298/1000, total reward: 120.200, entropy_coef: 0.0112
# Episode 299/1000, total reward: 164.000, entropy_coef: 0.0112
# Episode 300/1000, total reward: 196.000, entropy_coef: 0.0111
# Episode 301/1000, total reward: 108.000, entropy_coef: 0.0111
# Episode 302/1000, total reward: 97.400, entropy_coef: 0.0110
# Episode 303/1000, total reward: 174.000, entropy_coef: 0.0109
# Episode 304/1000, total reward: 174.000, entropy_coef: 0.0109
# Episode 305/1000, total reward: 229.000, entropy_coef: 0.0108
# Episode 306/1000, total reward: 229.000, entropy_coef: 0.0108
# Episode 307/1000, total reward: 163.400, entropy_coef: 0.0107
# Episode 308/1000, total reward: 185.000, entropy_coef: 0.0107
# Episode 309/1000, total reward: 186.000, entropy_coef: 0.0106
# Episode 310/1000, total reward: 163.600, entropy_coef: 0.0106
# Episode 311/1000, total reward: 163.200, entropy_coef: 0.0105
# Episode 312/1000, total reward: 196.000, entropy_coef: 0.0105
# Episode 313/1000, total reward: 218.400, entropy_coef: 0.0104
# Episode 314/1000, total reward: 218.000, entropy_coef: 0.0104
# Episode 315/1000, total reward: 218.200, entropy_coef: 0.0103
# Episode 316/1000, total reward: 141.000, entropy_coef: 0.0103
# Episode 317/1000, total reward: 218.000, entropy_coef: 0.0102
# Episode 318/1000, total reward: 163.000, entropy_coef: 0.0102
# Episode 319/1000, total reward: 130.000, entropy_coef: 0.0101
# Episode 320/1000, total reward: 152.000, entropy_coef: 0.0101
# Episode 321/1000, total reward: 196.000, entropy_coef: 0.0100
# Episode 322/1000, total reward: 175.200, entropy_coef: 0.0100
# Episode 323/1000, total reward: 229.000, entropy_coef: 0.0099
# Episode 324/1000, total reward: 240.000, entropy_coef: 0.0099
# Episode 325/1000, total reward: 229.000, entropy_coef: 0.0098
# Episode 326/1000, total reward: 207.000, entropy_coef: 0.0098
# Episode 327/1000, total reward: 229.000, entropy_coef: 0.0097
# Episode 328/1000, total reward: 218.000, entropy_coef: 0.0097
# Episode 329/1000, total reward: 218.000, entropy_coef: 0.0096
# Episode 330/1000, total reward: 218.000, entropy_coef: 0.0096
# Episode 331/1000, total reward: 196.000, entropy_coef: 0.0095
# Episode 332/1000, total reward: 207.600, entropy_coef: 0.0095
# Episode 333/1000, total reward: 240.000, entropy_coef: 0.0094
# Episode 334/1000, total reward: 240.000, entropy_coef: 0.0094
# Episode 335/1000, total reward: 207.000, entropy_coef: 0.0093
# Episode 336/1000, total reward: 186.000, entropy_coef: 0.0093
# Episode 337/1000, total reward: 218.000, entropy_coef: 0.0092
# Episode 338/1000, total reward: 240.000, entropy_coef: 0.0092
# Episode 339/1000, total reward: 130.000, entropy_coef: 0.0091
# Episode 340/1000, total reward: 142.000, entropy_coef: 0.0091
# Episode 341/1000, total reward: 196.000, entropy_coef: 0.0090
# Episode 342/1000, total reward: 218.000, entropy_coef: 0.0090
# Episode 343/1000, total reward: 240.000, entropy_coef: 0.0090
# Episode 344/1000, total reward: 240.000, entropy_coef: 0.0089
# Episode 345/1000, total reward: 153.000, entropy_coef: 0.0089
# Episode 346/1000, total reward: 207.000, entropy_coef: 0.0088
# Episode 347/1000, total reward: 218.000, entropy_coef: 0.0088
# Episode 348/1000, total reward: 229.000, entropy_coef: 0.0087
# Episode 349/1000, total reward: 229.000, entropy_coef: 0.0087
# Episode 350/1000, total reward: 163.400, entropy_coef: 0.0087
# Episode 351/1000, total reward: 229.600, entropy_coef: 0.0086
# Episode 352/1000, total reward: 240.000, entropy_coef: 0.0086
# Episode 353/1000, total reward: 218.600, entropy_coef: 0.0085
# Episode 354/1000, total reward: 196.000, entropy_coef: 0.0085
# Episode 355/1000, total reward: 218.000, entropy_coef: 0.0084
# Episode 356/1000, total reward: 196.000, entropy_coef: 0.0084
# Episode 357/1000, total reward: 108.000, entropy_coef: 0.0084
# Episode 358/1000, total reward: 207.000, entropy_coef: 0.0083
# Episode 359/1000, total reward: 207.000, entropy_coef: 0.0083
# Episode 360/1000, total reward: 218.000, entropy_coef: 0.0082
# Episode 361/1000, total reward: 185.600, entropy_coef: 0.0082
# Episode 362/1000, total reward: 97.000, entropy_coef: 0.0081
# Episode 363/1000, total reward: 240.000, entropy_coef: 0.0081
# Episode 364/1000, total reward: 152.600, entropy_coef: 0.0081
# Episode 365/1000, total reward: 207.000, entropy_coef: 0.0080
# Episode 366/1000, total reward: 229.000, entropy_coef: 0.0080
# Episode 367/1000, total reward: 218.000, entropy_coef: 0.0079
# Episode 368/1000, total reward: 240.000, entropy_coef: 0.0079
# Episode 369/1000, total reward: 141.000, entropy_coef: 0.0079
# Episode 370/1000, total reward: 240.000, entropy_coef: 0.0078
# Episode 371/1000, total reward: 196.000, entropy_coef: 0.0078
# Episode 372/1000, total reward: 240.000, entropy_coef: 0.0077
# Episode 373/1000, total reward: 229.400, entropy_coef: 0.0077
# Episode 374/1000, total reward: 174.400, entropy_coef: 0.0077
# Episode 375/1000, total reward: 218.000, entropy_coef: 0.0076
# Episode 376/1000, total reward: 196.600, entropy_coef: 0.0076
# Episode 377/1000, total reward: 240.000, entropy_coef: 0.0076
# Episode 378/1000, total reward: 240.000, entropy_coef: 0.0075
# Episode 379/1000, total reward: 240.000, entropy_coef: 0.0075
# Episode 380/1000, total reward: 130.600, entropy_coef: 0.0074
# Episode 381/1000, total reward: 174.000, entropy_coef: 0.0074
# Episode 382/1000, total reward: 185.000, entropy_coef: 0.0074
# Episode 383/1000, total reward: 163.000, entropy_coef: 0.0073
# Episode 384/1000, total reward: 218.000, entropy_coef: 0.0073
# Episode 385/1000, total reward: 64.000, entropy_coef: 0.0073
# Episode 386/1000, total reward: 185.000, entropy_coef: 0.0072
# Episode 387/1000, total reward: 152.000, entropy_coef: 0.0072
# Episode 388/1000, total reward: 163.600, entropy_coef: 0.0072
# Episode 389/1000, total reward: 229.000, entropy_coef: 0.0071
# Episode 390/1000, total reward: 196.000, entropy_coef: 0.0071
# Episode 391/1000, total reward: 218.000, entropy_coef: 0.0070
# Episode 392/1000, total reward: 207.000, entropy_coef: 0.0070
# Episode 393/1000, total reward: 207.000, entropy_coef: 0.0070
# Episode 394/1000, total reward: 196.000, entropy_coef: 0.0069
# Episode 395/1000, total reward: 108.000, entropy_coef: 0.0069
# Episode 396/1000, total reward: 108.000, entropy_coef: 0.0069
# Episode 397/1000, total reward: 53.000, entropy_coef: 0.0068
# Episode 398/1000, total reward: 207.000, entropy_coef: 0.0068
# Episode 399/1000, total reward: 174.600, entropy_coef: 0.0068
# Episode 400/1000, total reward: 196.000, entropy_coef: 0.0067
# Episode 401/1000, total reward: 152.000, entropy_coef: 0.0067
# Episode 402/1000, total reward: 218.600, entropy_coef: 0.0067
# Episode 403/1000, total reward: 185.000, entropy_coef: 0.0066
# Episode 404/1000, total reward: 196.600, entropy_coef: 0.0066
# Episode 405/1000, total reward: 229.000, entropy_coef: 0.0066
# Episode 406/1000, total reward: 240.000, entropy_coef: 0.0065
# Episode 407/1000, total reward: 218.000, entropy_coef: 0.0065
# Episode 408/1000, total reward: 229.000, entropy_coef: 0.0065
# Episode 409/1000, total reward: 196.400, entropy_coef: 0.0064
# Episode 410/1000, total reward: 229.000, entropy_coef: 0.0064
# Episode 411/1000, total reward: 229.000, entropy_coef: 0.0064
# Episode 412/1000, total reward: 240.000, entropy_coef: 0.0063
# Episode 413/1000, total reward: 130.200, entropy_coef: 0.0063
# Episode 414/1000, total reward: 229.000, entropy_coef: 0.0063
# Episode 415/1000, total reward: 240.000, entropy_coef: 0.0062
# Episode 416/1000, total reward: 240.000, entropy_coef: 0.0062
# Episode 417/1000, total reward: 196.600, entropy_coef: 0.0062
# Episode 418/1000, total reward: 218.000, entropy_coef: 0.0062
# Episode 419/1000, total reward: 152.200, entropy_coef: 0.0061
# Episode 420/1000, total reward: 240.000, entropy_coef: 0.0061
# Episode 421/1000, total reward: 207.000, entropy_coef: 0.0061
# Episode 422/1000, total reward: 174.000, entropy_coef: 0.0060
# Episode 423/1000, total reward: 196.000, entropy_coef: 0.0060
# Episode 424/1000, total reward: 218.000, entropy_coef: 0.0060
# Episode 425/1000, total reward: 174.400, entropy_coef: 0.0059
# Episode 426/1000, total reward: 130.600, entropy_coef: 0.0059
# Episode 427/1000, total reward: 141.000, entropy_coef: 0.0059
# Episode 428/1000, total reward: 75.600, entropy_coef: 0.0059
# Episode 429/1000, total reward: 218.000, entropy_coef: 0.0058
# Episode 430/1000, total reward: 196.600, entropy_coef: 0.0058
# Episode 431/1000, total reward: 240.000, entropy_coef: 0.0058
# Episode 432/1000, total reward: 229.000, entropy_coef: 0.0057
# Episode 433/1000, total reward: 163.000, entropy_coef: 0.0057
# Episode 434/1000, total reward: 240.000, entropy_coef: 0.0057
# Episode 435/1000, total reward: 207.200, entropy_coef: 0.0056
# Episode 436/1000, total reward: 185.000, entropy_coef: 0.0056
# Episode 437/1000, total reward: 240.000, entropy_coef: 0.0056
# Episode 438/1000, total reward: 218.000, entropy_coef: 0.0056
# Episode 439/1000, total reward: 196.000, entropy_coef: 0.0055
# Episode 440/1000, total reward: 240.000, entropy_coef: 0.0055
# Episode 441/1000, total reward: 185.600, entropy_coef: 0.0055
# Episode 442/1000, total reward: 240.000, entropy_coef: 0.0055
# Episode 443/1000, total reward: 218.000, entropy_coef: 0.0054
# Episode 444/1000, total reward: 207.000, entropy_coef: 0.0054
# Episode 445/1000, total reward: 218.000, entropy_coef: 0.0054
# Episode 446/1000, total reward: 207.600, entropy_coef: 0.0053
# Episode 447/1000, total reward: 174.000, entropy_coef: 0.0053
# Episode 448/1000, total reward: 218.000, entropy_coef: 0.0053
# Episode 449/1000, total reward: 240.000, entropy_coef: 0.0053
# Episode 450/1000, total reward: 207.000, entropy_coef: 0.0052
# Episode 451/1000, total reward: 196.000, entropy_coef: 0.0052
# Episode 452/1000, total reward: 152.400, entropy_coef: 0.0052
# Episode 453/1000, total reward: 53.000, entropy_coef: 0.0052
# Episode 454/1000, total reward: 240.000, entropy_coef: 0.0051
# Episode 455/1000, total reward: 174.000, entropy_coef: 0.0051
# Episode 456/1000, total reward: 196.000, entropy_coef: 0.0051
# Episode 457/1000, total reward: 196.400, entropy_coef: 0.0051
# Episode 458/1000, total reward: 229.600, entropy_coef: 0.0050
# Episode 459/1000, total reward: 152.400, entropy_coef: 0.0050
# Episode 460/1000, total reward: 9.000, entropy_coef: 0.0050
# Episode 461/1000, total reward: 163.600, entropy_coef: 0.0050
# Episode 462/1000, total reward: 240.000, entropy_coef: 0.0049
# Episode 463/1000, total reward: 240.000, entropy_coef: 0.0049
# Episode 464/1000, total reward: 163.400, entropy_coef: 0.0049
# Episode 465/1000, total reward: 196.000, entropy_coef: 0.0049
# Episode 466/1000, total reward: 207.000, entropy_coef: 0.0048
# Episode 467/1000, total reward: 218.000, entropy_coef: 0.0048
# Episode 468/1000, total reward: 229.000, entropy_coef: 0.0048
# Episode 469/1000, total reward: 207.000, entropy_coef: 0.0048
# Episode 470/1000, total reward: 185.600, entropy_coef: 0.0047
# Episode 471/1000, total reward: 229.000, entropy_coef: 0.0047
# Episode 472/1000, total reward: 185.600, entropy_coef: 0.0047
# Episode 473/1000, total reward: 240.000, entropy_coef: 0.0047
# Episode 474/1000, total reward: 174.400, entropy_coef: 0.0046
# Episode 475/1000, total reward: 240.000, entropy_coef: 0.0046
# Episode 476/1000, total reward: 152.000, entropy_coef: 0.0046
# Episode 477/1000, total reward: 229.000, entropy_coef: 0.0046
# Episode 478/1000, total reward: 108.000, entropy_coef: 0.0046
# Episode 479/1000, total reward: 174.600, entropy_coef: 0.0045
# Episode 480/1000, total reward: 130.000, entropy_coef: 0.0045
# Episode 481/1000, total reward: 141.000, entropy_coef: 0.0045
# Episode 482/1000, total reward: 207.000, entropy_coef: 0.0045
# Episode 483/1000, total reward: 207.000, entropy_coef: 0.0044
# Episode 484/1000, total reward: 164.200, entropy_coef: 0.0044
# Episode 485/1000, total reward: 218.000, entropy_coef: 0.0044
# Episode 486/1000, total reward: 141.000, entropy_coef: 0.0044
# Episode 487/1000, total reward: 141.000, entropy_coef: 0.0044
# Episode 488/1000, total reward: 152.000, entropy_coef: 0.0043
# Episode 489/1000, total reward: 207.400, entropy_coef: 0.0043
# Episode 490/1000, total reward: 185.000, entropy_coef: 0.0043
# Episode 491/1000, total reward: 218.000, entropy_coef: 0.0043
# Episode 492/1000, total reward: 163.000, entropy_coef: 0.0042
# Episode 493/1000, total reward: 152.000, entropy_coef: 0.0042
# Episode 494/1000, total reward: 218.000, entropy_coef: 0.0042
# Episode 495/1000, total reward: 207.000, entropy_coef: 0.0042
# Episode 496/1000, total reward: 185.600, entropy_coef: 0.0042
# Episode 497/1000, total reward: 218.000, entropy_coef: 0.0041
# Episode 498/1000, total reward: 240.000, entropy_coef: 0.0041
# Episode 499/1000, total reward: 207.000, entropy_coef: 0.0041
# Episode 500/1000, total reward: 229.000, entropy_coef: 0.0041
# Episode 501/1000, total reward: 196.400, entropy_coef: 0.0041
# Episode 502/1000, total reward: 240.000, entropy_coef: 0.0040
# Episode 503/1000, total reward: 185.000, entropy_coef: 0.0040
# Episode 504/1000, total reward: 229.600, entropy_coef: 0.0040
# Episode 505/1000, total reward: 218.000, entropy_coef: 0.0040
# Episode 506/1000, total reward: 163.600, entropy_coef: 0.0040
# Episode 507/1000, total reward: 153.000, entropy_coef: 0.0039
# Episode 508/1000, total reward: 64.400, entropy_coef: 0.0039
# Episode 509/1000, total reward: 196.000, entropy_coef: 0.0039
# Episode 510/1000, total reward: 218.000, entropy_coef: 0.0039
# Episode 511/1000, total reward: 207.000, entropy_coef: 0.0039
# Episode 512/1000, total reward: 196.000, entropy_coef: 0.0038
# Episode 513/1000, total reward: 207.000, entropy_coef: 0.0038
# Episode 514/1000, total reward: 163.000, entropy_coef: 0.0038
# Episode 515/1000, total reward: 240.000, entropy_coef: 0.0038
# Episode 516/1000, total reward: 130.600, entropy_coef: 0.0038
# Episode 517/1000, total reward: 153.000, entropy_coef: 0.0037
# Episode 518/1000, total reward: 240.000, entropy_coef: 0.0037
# Episode 519/1000, total reward: 174.000, entropy_coef: 0.0037
# Episode 520/1000, total reward: 207.600, entropy_coef: 0.0037
# Episode 521/1000, total reward: 152.000, entropy_coef: 0.0037
# Episode 522/1000, total reward: 196.000, entropy_coef: 0.0037
# Episode 523/1000, total reward: 207.000, entropy_coef: 0.0036
# Episode 524/1000, total reward: 207.000, entropy_coef: 0.0036
# Episode 525/1000, total reward: 207.000, entropy_coef: 0.0036
# Episode 526/1000, total reward: 240.000, entropy_coef: 0.0036
# Episode 527/1000, total reward: 185.000, entropy_coef: 0.0036
# Episode 528/1000, total reward: 240.000, entropy_coef: 0.0035
# Episode 529/1000, total reward: 185.600, entropy_coef: 0.0035
# Episode 530/1000, total reward: 207.000, entropy_coef: 0.0035
# Episode 531/1000, total reward: 196.000, entropy_coef: 0.0035
# Episode 532/1000, total reward: 207.000, entropy_coef: 0.0035
# Episode 533/1000, total reward: 163.000, entropy_coef: 0.0035
# Episode 534/1000, total reward: 163.000, entropy_coef: 0.0034
# Episode 535/1000, total reward: 196.000, entropy_coef: 0.0034
# Episode 536/1000, total reward: 207.000, entropy_coef: 0.0034
# Episode 537/1000, total reward: 174.000, entropy_coef: 0.0034
# Episode 538/1000, total reward: 218.000, entropy_coef: 0.0034
# Episode 539/1000, total reward: 229.000, entropy_coef: 0.0034
# Episode 540/1000, total reward: 240.000, entropy_coef: 0.0033
# Episode 541/1000, total reward: 196.000, entropy_coef: 0.0033
# Episode 542/1000, total reward: 240.000, entropy_coef: 0.0033
# Episode 543/1000, total reward: 218.000, entropy_coef: 0.0033
# Episode 544/1000, total reward: 207.000, entropy_coef: 0.0033
# Episode 545/1000, total reward: 207.000, entropy_coef: 0.0033
# Episode 546/1000, total reward: 229.000, entropy_coef: 0.0032
# Episode 547/1000, total reward: 240.000, entropy_coef: 0.0032
# Episode 548/1000, total reward: 207.000, entropy_coef: 0.0032
# Episode 549/1000, total reward: 185.000, entropy_coef: 0.0032
# Episode 550/1000, total reward: 240.000, entropy_coef: 0.0032
# Episode 551/1000, total reward: 229.000, entropy_coef: 0.0032
# Episode 552/1000, total reward: 218.000, entropy_coef: 0.0031
# Episode 553/1000, total reward: 229.000, entropy_coef: 0.0031
# Episode 554/1000, total reward: 218.000, entropy_coef: 0.0031
# Episode 555/1000, total reward: 229.000, entropy_coef: 0.0031
# Episode 556/1000, total reward: 240.000, entropy_coef: 0.0031
# Episode 557/1000, total reward: 229.000, entropy_coef: 0.0031
# Episode 558/1000, total reward: 218.000, entropy_coef: 0.0030
# Episode 559/1000, total reward: 240.000, entropy_coef: 0.0030
# Episode 560/1000, total reward: 207.000, entropy_coef: 0.0030
# Episode 561/1000, total reward: 174.000, entropy_coef: 0.0030
# Episode 562/1000, total reward: 218.000, entropy_coef: 0.0030
# Episode 563/1000, total reward: 240.000, entropy_coef: 0.0030
# Episode 564/1000, total reward: 240.000, entropy_coef: 0.0030
# Episode 565/1000, total reward: 218.000, entropy_coef: 0.0029
# Episode 566/1000, total reward: 240.000, entropy_coef: 0.0029
# Episode 567/1000, total reward: 229.000, entropy_coef: 0.0029
# Episode 568/1000, total reward: 240.000, entropy_coef: 0.0029
# Episode 569/1000, total reward: 229.000, entropy_coef: 0.0029
# Episode 570/1000, total reward: 207.600, entropy_coef: 0.0029
# Episode 571/1000, total reward: 240.000, entropy_coef: 0.0029
# Episode 572/1000, total reward: 218.000, entropy_coef: 0.0028
# Episode 573/1000, total reward: 218.000, entropy_coef: 0.0028
# Episode 574/1000, total reward: 207.000, entropy_coef: 0.0028
# Episode 575/1000, total reward: 240.000, entropy_coef: 0.0028
# Episode 576/1000, total reward: 240.000, entropy_coef: 0.0028
# Episode 577/1000, total reward: 229.000, entropy_coef: 0.0028
# Episode 578/1000, total reward: 218.000, entropy_coef: 0.0028
# Episode 579/1000, total reward: 240.000, entropy_coef: 0.0027
# Episode 580/1000, total reward: 196.000, entropy_coef: 0.0027
# Episode 581/1000, total reward: 229.000, entropy_coef: 0.0027
# Episode 582/1000, total reward: 218.000, entropy_coef: 0.0027
# Episode 583/1000, total reward: 229.000, entropy_coef: 0.0027
# Episode 584/1000, total reward: 240.000, entropy_coef: 0.0027
# Episode 585/1000, total reward: 240.000, entropy_coef: 0.0027
# Episode 586/1000, total reward: 240.000, entropy_coef: 0.0027
# Episode 587/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 588/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 589/1000, total reward: 240.000, entropy_coef: 0.0026
# Episode 590/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 591/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 592/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 593/1000, total reward: 218.000, entropy_coef: 0.0026
# Episode 594/1000, total reward: 218.000, entropy_coef: 0.0025
# Episode 595/1000, total reward: 240.000, entropy_coef: 0.0025
# Episode 596/1000, total reward: 240.000, entropy_coef: 0.0025
# Episode 597/1000, total reward: 207.000, entropy_coef: 0.0025
# Episode 598/1000, total reward: 218.000, entropy_coef: 0.0025
# Episode 599/1000, total reward: 240.000, entropy_coef: 0.0025
# Episode 600/1000, total reward: 218.000, entropy_coef: 0.0025
# Episode 601/1000, total reward: 240.000, entropy_coef: 0.0025
# Episode 602/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 603/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 604/1000, total reward: 185.000, entropy_coef: 0.0024
# Episode 605/1000, total reward: 229.000, entropy_coef: 0.0024
# Episode 606/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 607/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 608/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 609/1000, total reward: 240.000, entropy_coef: 0.0024
# Episode 610/1000, total reward: 218.000, entropy_coef: 0.0023
# Episode 611/1000, total reward: 218.000, entropy_coef: 0.0023
# Episode 612/1000, total reward: 207.000, entropy_coef: 0.0023
# Episode 613/1000, total reward: 240.000, entropy_coef: 0.0023
# Episode 614/1000, total reward: 218.000, entropy_coef: 0.0023
# Episode 615/1000, total reward: 240.000, entropy_coef: 0.0023
# Episode 616/1000, total reward: 218.000, entropy_coef: 0.0023
# Episode 617/1000, total reward: 240.000, entropy_coef: 0.0023
# Episode 618/1000, total reward: 240.000, entropy_coef: 0.0023
# Episode 619/1000, total reward: 218.000, entropy_coef: 0.0022
# Episode 620/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 621/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 622/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 623/1000, total reward: 218.000, entropy_coef: 0.0022
# Episode 624/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 625/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 626/1000, total reward: 218.000, entropy_coef: 0.0022
# Episode 627/1000, total reward: 240.000, entropy_coef: 0.0022
# Episode 628/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 629/1000, total reward: 218.000, entropy_coef: 0.0021
# Episode 630/1000, total reward: 218.000, entropy_coef: 0.0021
# Episode 631/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 632/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 633/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 634/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 635/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 636/1000, total reward: 218.000, entropy_coef: 0.0021
# Episode 637/1000, total reward: 240.000, entropy_coef: 0.0021
# Episode 638/1000, total reward: 218.000, entropy_coef: 0.0020
# Episode 639/1000, total reward: 207.000, entropy_coef: 0.0020
# Episode 640/1000, total reward: 240.000, entropy_coef: 0.0020
# Episode 641/1000, total reward: 240.000, entropy_coef: 0.0020
# Episode 642/1000, total reward: 240.000, entropy_coef: 0.0020
# Episode 643/1000, total reward: 218.000, entropy_coef: 0.0020
# Episode 644/1000, total reward: 196.000, entropy_coef: 0.0020
# Episode 645/1000, total reward: 174.000, entropy_coef: 0.0020
# Episode 646/1000, total reward: 240.000, entropy_coef: 0.0020
# Episode 647/1000, total reward: 218.000, entropy_coef: 0.0020
# Episode 648/1000, total reward: 174.800, entropy_coef: 0.0019
# Episode 649/1000, total reward: 240.000, entropy_coef: 0.0019
# Episode 650/1000, total reward: 185.000, entropy_coef: 0.0019
# Episode 651/1000, total reward: 240.000, entropy_coef: 0.0019
# Episode 652/1000, total reward: 229.000, entropy_coef: 0.0019
# Episode 653/1000, total reward: 240.000, entropy_coef: 0.0019
# Episode 654/1000, total reward: 240.000, entropy_coef: 0.0019
# Episode 655/1000, total reward: 185.000, entropy_coef: 0.0019
# Episode 656/1000, total reward: 218.000, entropy_coef: 0.0019
# Episode 657/1000, total reward: 218.000, entropy_coef: 0.0019
# Episode 658/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 659/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 660/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 661/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 662/1000, total reward: 185.000, entropy_coef: 0.0018
# Episode 663/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 664/1000, total reward: 218.000, entropy_coef: 0.0018
# Episode 665/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 666/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 667/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 668/1000, total reward: 240.000, entropy_coef: 0.0018
# Episode 669/1000, total reward: 229.600, entropy_coef: 0.0017
# Episode 670/1000, total reward: 218.000, entropy_coef: 0.0017
# Episode 671/1000, total reward: 240.000, entropy_coef: 0.0017
# Episode 672/1000, total reward: 196.000, entropy_coef: 0.0017
# Episode 673/1000, total reward: 240.000, entropy_coef: 0.0017
# Episode 674/1000, total reward: 196.000, entropy_coef: 0.0017
# Episode 675/1000, total reward: 218.000, entropy_coef: 0.0017
# Episode 676/1000, total reward: 229.000, entropy_coef: 0.0017
# Episode 677/1000, total reward: 218.000, entropy_coef: 0.0017
# Episode 678/1000, total reward: 174.000, entropy_coef: 0.0017
# Episode 679/1000, total reward: 240.000, entropy_coef: 0.0017
# Episode 680/1000, total reward: 196.000, entropy_coef: 0.0017
# Episode 681/1000, total reward: 218.000, entropy_coef: 0.0016
# Episode 682/1000, total reward: 163.600, entropy_coef: 0.0016
# Episode 683/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 684/1000, total reward: 207.000, entropy_coef: 0.0016
# Episode 685/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 686/1000, total reward: 163.400, entropy_coef: 0.0016
# Episode 687/1000, total reward: 152.000, entropy_coef: 0.0016
# Episode 688/1000, total reward: 218.000, entropy_coef: 0.0016
# Episode 689/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 690/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 691/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 692/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 693/1000, total reward: 240.000, entropy_coef: 0.0016
# Episode 694/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 695/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 696/1000, total reward: 218.000, entropy_coef: 0.0015
# Episode 697/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 698/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 699/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 700/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 701/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 702/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 703/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 704/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 705/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 706/1000, total reward: 240.000, entropy_coef: 0.0015
# Episode 707/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 708/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 709/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 710/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 711/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 712/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 713/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 714/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 715/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 716/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 717/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 718/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 719/1000, total reward: 229.400, entropy_coef: 0.0014
# Episode 720/1000, total reward: 240.000, entropy_coef: 0.0014
# Episode 721/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 722/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 723/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 724/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 725/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 726/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 727/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 728/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 729/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 730/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 731/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 732/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 733/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 734/1000, total reward: 218.000, entropy_coef: 0.0013
# Episode 735/1000, total reward: 240.000, entropy_coef: 0.0013
# Episode 736/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 737/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 738/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 739/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 740/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 741/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 742/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 743/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 744/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 745/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 746/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 747/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 748/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 749/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 750/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 751/1000, total reward: 240.000, entropy_coef: 0.0012
# Episode 752/1000, total reward: 229.000, entropy_coef: 0.0012
# Episode 753/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 754/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 755/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 756/1000, total reward: 218.000, entropy_coef: 0.0011
# Episode 757/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 758/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 759/1000, total reward: 229.400, entropy_coef: 0.0011
# Episode 760/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 761/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 762/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 763/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 764/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 765/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 766/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 767/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 768/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 769/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 770/1000, total reward: 240.000, entropy_coef: 0.0011
# Episode 771/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 772/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 773/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 774/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 775/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 776/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 777/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 778/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 779/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 780/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 781/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 782/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 783/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 784/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 785/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 786/1000, total reward: 218.000, entropy_coef: 0.0010
# Episode 787/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 788/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 789/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 790/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 791/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 792/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 793/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 794/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 795/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 796/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 797/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 798/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 799/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 800/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 801/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 802/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 803/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 804/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 805/1000, total reward: 218.000, entropy_coef: 0.0010
# Episode 806/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 807/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 808/1000, total reward: 218.000, entropy_coef: 0.0010
# Episode 809/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 810/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 811/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 812/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 813/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 814/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 815/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 816/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 817/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 818/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 819/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 820/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 821/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 822/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 823/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 824/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 825/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 826/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 827/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 828/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 829/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 830/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 831/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 832/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 833/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 834/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 835/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 836/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 837/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 838/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 839/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 840/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 841/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 842/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 843/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 844/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 845/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 846/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 847/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 848/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 849/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 850/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 851/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 852/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 853/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 854/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 855/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 856/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 857/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 858/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 859/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 860/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 861/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 862/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 863/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 864/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 865/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 866/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 867/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 868/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 869/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 870/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 871/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 872/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 873/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 874/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 875/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 876/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 877/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 878/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 879/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 880/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 881/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 882/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 883/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 884/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 885/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 886/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 887/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 888/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 889/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 890/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 891/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 892/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 893/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 894/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 895/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 896/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 897/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 898/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 899/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 900/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 901/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 902/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 903/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 904/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 905/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 906/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 907/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 908/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 909/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 910/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 911/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 912/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 913/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 914/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 915/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 916/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 917/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 918/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 919/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 920/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 921/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 922/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 923/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 924/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 925/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 926/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 927/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 928/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 929/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 930/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 931/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 932/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 933/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 934/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 935/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 936/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 937/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 938/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 939/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 940/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 941/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 942/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 943/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 944/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 945/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 946/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 947/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 948/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 949/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 950/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 951/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 952/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 953/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 954/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 955/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 956/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 957/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 958/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 959/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 960/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 961/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 962/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 963/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 964/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 965/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 966/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 967/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 968/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 969/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 970/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 971/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 972/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 973/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 974/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 975/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 976/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 977/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 978/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 979/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 980/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 981/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 982/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 983/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 984/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 985/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 986/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 987/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 988/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 989/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 990/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 991/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 992/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 993/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 994/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 995/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 996/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 997/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 998/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 999/1000, total reward: 240.000, entropy_coef: 0.0010
# Episode 1000/1000, total reward: 240.000, entropy_coef: 0.0010

# %%
# === Plot learning curve with running average ===
window = 10                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=2, label=f"Running Avg (window={window})")
plt.xlabel("Episode")
plt.ylabel("Smoothed Total Reward")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %%
# # ============================================================
# # 1️⃣  Actor-Critic Network
# # ============================================================
# class ActorCritic(nn.Module):
#     def __init__(self, state_dim, action_dim):
#         super().__init__()
#         self.actor = nn.Sequential(
#             nn.Linear(state_dim, 64),
#             nn.ReLU(),
#             nn.Linear(64, action_dim),
#             nn.Softmax(dim=-1)
#         )
#         self.critic = nn.Sequential(
#             nn.Linear(state_dim, 64),
#             nn.ReLU(),
#             nn.Linear(64, 1)
#         )

#     def forward(self, state):
#         probs = self.actor(state)
#         value = self.critic(state)
#         return probs, value


# # ============================================================
# # 2️⃣  PPO Agent
# # ============================================================
# class PPOAgent:
#     def __init__(self, state_dim, action_dim, lr=3e-4, gamma=0.99, eps_clip=0.2):
#         self.gamma = gamma
#         self.eps_clip = eps_clip

#         self.model = ActorCritic(state_dim, action_dim)
#         self.optimizer = optim.Adam(self.model.parameters(), lr=lr)

#     def select_action(self, state):
#         state = torch.tensor(state, dtype=torch.float32)
#         probs, value = self.model(state)
#         dist = torch.distributions.Categorical(probs)
#         action = dist.sample()
#         return action.item(), dist.log_prob(action), value

#     def compute_advantages(self, rewards, values, dones):
#         advantages = []
#         gae = 0
#         values = values.detach().numpy()  # Detach to avoid autograd graph reuse
#         for t in reversed(range(len(rewards))):
#             delta = rewards[t] + self.gamma * values[t + 1] * (1 - dones[t]) - values[t]
#             gae = delta + self.gamma * 0.95 * (1 - dones[t]) * gae
#             advantages.insert(0, gae)
#         return torch.tensor(advantages, dtype=torch.float32)

#     def update(self, states, actions, log_probs_old, returns, advantages, epochs=5, batch_size=32):
#         advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

#         dataset_size = len(states)
#         for _ in range(epochs):
#             indices = np.arange(dataset_size)
#             np.random.shuffle(indices)

#             for start in range(0, dataset_size, batch_size):
#                 end = start + batch_size
#                 batch_idx = indices[start:end]

#                 batch_states = states[batch_idx]
#                 batch_actions = actions[batch_idx]
#                 batch_log_probs_old = log_probs_old[batch_idx]
#                 batch_advantages = advantages[batch_idx]
#                 batch_returns = returns[batch_idx]

#                 probs, values = self.model(batch_states)
#                 dist = torch.distributions.Categorical(probs)
#                 log_probs = dist.log_prob(batch_actions)

#                 ratios = torch.exp(log_probs - batch_log_probs_old.detach())
#                 surr1 = ratios * batch_advantages
#                 surr2 = torch.clamp(ratios, 1 - self.eps_clip, 1 + self.eps_clip) * batch_advantages
#                 actor_loss = -torch.min(surr1, surr2).mean()

#                 #critic_loss = F.mse_loss(values.squeeze(), batch_returns)
#                 critic_loss = F.mse_loss(values.view_as(batch_returns), batch_returns)

#                 entropy_loss = dist.entropy().mean()

#                 loss = actor_loss + 0.5 * critic_loss - 0.01 * entropy_loss

#                 self.optimizer.zero_grad()
#                 loss.backward()
#                 self.optimizer.step()


# # ============================================================
# # 3️⃣  Training Loop
# # ============================================================
# env = gym.make("CartPole-v1")

# state_dim = env.observation_space.shape[0]
# action_dim = env.action_space.n
# agent = PPOAgent(state_dim, action_dim)

# num_episodes = 100
# reward_history = []

# for ep in range(num_episodes):
#     state, _ = env.reset()
#     done = False

#     states, actions, log_probs, rewards, values, dones = [], [], [], [], [], []

#     while not done:
#         action, log_prob, value = agent.select_action(state)

#         next_state, reward, done, _, _ = env.step(action)

#         # Store transition
#         states.append(torch.tensor(state, dtype=torch.float32))
#         actions.append(torch.tensor(action))
#         log_probs.append(log_prob.detach())  # Detach avoids autograd reuse
#         values.append(value.detach())        # Detach avoids autograd reuse
#         rewards.append(reward)
#         dones.append(float(done))

#         state = next_state

#     # Bootstrap final state value
#     with torch.no_grad():
#         _, next_value = agent.model(torch.tensor(state, dtype=torch.float32))
#     values.append(next_value.detach())

#     # Convert to tensors
#     rewards = torch.tensor(rewards, dtype=torch.float32)
#     values = torch.stack(values).squeeze()
#     dones = torch.tensor(dones, dtype=torch.float32)

#     advantages = agent.compute_advantages(rewards, values, dones)
#     returns = advantages + values[:-1]

#     # Stack rollout data
#     states = torch.stack(states)
#     actions = torch.stack(actions)
#     log_probs = torch.stack(log_probs)

#     # Update policy
#     agent.update(states, actions, log_probs, returns.detach(), advantages.detach())

#     total_reward = sum(rewards)
#     reward_history.append(total_reward)

#     if (ep + 1) % 10 == 0:
#         print(f"Episode {ep + 1}, Reward: {total_reward:.1f}, Avg(10): {np.mean(reward_history[-10:]):.1f}")

# env.close()

# # --- Plot learning curve ---
# plt.plot(reward_history)
# plt.xlabel("Episode")
# plt.ylabel("Total Reward")
# plt.title("PPO on CartPole-v1")
# plt.grid(True)
# plt.show()
