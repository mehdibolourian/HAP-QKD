# %%
from libraries import *
# Out:
# /home/mehdi/rl-env/bin/python3

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-12-17

# %%
gnodes, hnodes, links, demands = init_setup_real()

nodes = gnodes + hnodes
# Out:
#      Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0       0.0     279.000000     49.000000  25000.00000
# 1    3600.0     278.974006     49.042329  23672.57558
# 4    7200.0     278.932833     49.055108  22986.64633
# 7   10800.0     278.900893     49.018890  19378.08451
# 10  14400.0     278.989935     48.980466  20387.52864
# 13  18000.0     279.006678     48.992932  21378.46182
# 16  21600.0     279.038680     49.008456  21722.88519
# 19  25200.0     279.061682     49.024487  23068.06755
# 22  28800.0     279.067620     49.034208  22980.28988
# 25  32400.0     279.080779     49.013625  23209.52264
# 28  36000.0     279.075842     48.996233  23206.76795
# 31  39600.0     279.055069     48.999030  23206.48967
# 34  43200.0     279.049362     48.977709  23429.46557
# 37  46800.0     279.054583     49.001266  22740.73417
# 40  50400.0     278.985247     48.953397  21049.70677
# 43  54000.0     278.919923     48.953306  20474.85927
# 46  57600.0     278.939021     48.977959  19860.05593
# 49  61200.0     278.994659     48.965139  19574.35484
# 52  64800.0     279.043770     48.980250  19784.07311
# 55  68400.0     279.089595     48.954722  18975.42547
# 58  72000.0     279.162255     49.008611  19329.06589
# 61  75600.0     279.282568     49.086498  19451.14069
# 64  79200.0     279.469930     49.125324  21958.28937
# 67  82800.0     279.593425     49.128661  24030.70810
# 70  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=23 (24 time steps)
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval [0, 24) fully covered in checkpoint.

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# %%
# ---------- Hyperparams ----------
# GAMMA = 0.99
# GAE_LAMBDA = 0.95
# CLIP = 0.2
# LR = 3e-4
# EPOCHS = 4
# BATCH_SIZE = 64
# ENTROPY_COEF_INITIAL = 0.05         # >>> CHANGE - will decay over training
# ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
# ENTROPY_DECAY = 0.995               # >>> CHANGE
# VALUE_COEF = 0.5

GAMMA = 0.99
LR = 1e-4
CLIP = 0.3
EPOCHS = 3
BATCH_SIZE = 128
ENTROPY_COEF_INITIAL = 0.01
ENTROPY_COEF_MIN = 0.001
ENTROPY_DECAY = 0.999
GAE_LAMBDA = 0.95
VALUE_COEF = 0.5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# def build_state_vector_for_time(state_t, links, t, n_nodes=len(gnodes), normalize=True):
#     """
#     Build state vector for the QKD environment.

#     state_t["a"]: dict or list of QKP (stored key bits) for each link.
#     state_t["demands"]: list of demand objects with attributes (K_REQ, n1, n2).

#     Output vector structure:
#         [ QKP_link0, ..., QKP_linkL-1,
#           onehot_src_demand0..., onehot_dst_demand0..., KREQ_0,
#           onehot_src_demand1..., onehot_dst_demand1..., KREQ_1,
#           ... ]

#     Args:
#         state_t: dict for time t
#         links: list of link objects (or identifiers)
#         n_nodes: total number of GS/HAP nodes (used for one-hot encoding)
#         normalize: normalize QKP and KREQ values to [0, 1] range if True
#     """
#     # --- QKP per link ---
#     a_vec = np.array(
#         [state_t.get("a", {}).get(l, 0.0) for l in range(len(links))],
#         dtype=np.float32
#     )

#     # normalize QKP values if desired
#     if normalize and len(a_vec) > 0:
#         max_qkp = np.max(a_vec) if np.max(a_vec) > 0 else 1.0
#         a_vec = a_vec / max_qkp

#     # --- Encode demands ---
#     d_vec = []
#     for d in state_t.get("demands", []):
#         # normalize K_REQ
#         kreq = float(d.K_REQ[t])
#         if normalize and kreq > 0:
#             kreq = kreq / (kreq + 1e-6)  # simple scaling to (0,1)
#         # one-hot encode endpoints if n_nodes provided
#         if n_nodes is not None:
#             onehot_src = np.zeros(n_nodes, dtype=np.float32)
#             onehot_dst = np.zeros(n_nodes, dtype=np.float32)
#             if 0 <= gnodes.index(d.n1) < n_nodes:
#                 onehot_src[gnodes.index(d.n1)] = 1.0
#             if 0 <= gnodes.index(d.n2) < n_nodes:
#                 onehot_dst[gnodes.index(d.n2)] = 1.0
#             d_vec.extend(onehot_src.tolist() + onehot_dst.tolist() + [kreq])
#         else:
#             # fallback to simpler encoding if node info omitted
#             d_vec.append(kreq)

#     # --- Concatenate ---
#     state_vector = np.concatenate([a_vec, np.array(d_vec, dtype=np.float32)])
#     return state_vector

def build_state_vector_for_time(state_t, links, t, n_gnodes=len(gnodes), normalize=True):
    """
    Build state vector for the QKD environment.

    Includes:
    - QKP per link (normalized if normalize=True)
    - K_MAX per link (capacity)
    - For each demand: one-hot source, one-hot destination, normalized K_REQ

    State vector format:
    [ QKP_link0 .. QKP_link(L-1),
      KMAX_link0 .. KMAX_link(L-1),
      (src one-hot, dst one-hot, KREQ_demand0), ... ]
    """

    # -------------------------------
    # QKP / stored key bits per link
    # -------------------------------
    a_vec = np.array(
        [state_t.get("a", {}).get(idx_l, 0.0) for idx_l in range(len(links))],
        dtype=np.float32
    )

    if normalize:
        max_qkp = np.max(a_vec) if np.max(a_vec) > 0 else 1.0
        a_vec = a_vec / max_qkp

    # -----------------------------------------
    # Link Capacity (K_MAX per link)
    # -----------------------------------------
    if normalize:
        K_MAX_MAX = max(l.K_MAX[t] for l in links) + 1e-9  # avoid /0
        kmax_vec = np.array([l.K_MAX[t] / K_MAX_MAX for l in links], dtype=np.float32)
    else:
        kmax_vec = np.array([l.K_MAX[t] for l in links], dtype=np.float32)

    # ---------------------------
    # Encode demand information
    # ---------------------------
    K_REQ_MAX = max(d.K_REQ[t] for d in demands) + 1e-9

    d_vec = []

    # Loop over EVERY ordered GS pair (i → j, i ≠ j)
    for src in gnodes:
        for dst in gnodes:
            if src == dst:
                continue

            # Check whether there is a demand for this exact pair
            matched = next(
                (d for d in state_t.get("demands", [])
                 if d.n1 == src and d.n2 == dst),
                None
            )

            if matched:
                # Active demand exists
                kreq = float(matched.K_REQ[t])
                if normalize:
                    kreq = kreq / K_REQ_MAX

                src_idx = gnodes.index(src)
                dst_idx = gnodes.index(dst)

                src_norm = (src_idx + 1) / n_gnodes
                dst_norm = (dst_idx + 1) / n_gnodes

                d_vec.extend([src_norm, dst_norm, kreq])

            else:
                # No demand for this pair
                d_vec.extend([0.0, 0.0, 0.0])

    # ---------------------------
    # Concatenate full state
    # ---------------------------
    state_vector = np.concatenate(
        [a_vec, kmax_vec, np.array(d_vec, dtype=np.float32)]
    )

    return state_vector

def heuristic_policy(state_t, links, t):
    action = np.zeros(len(links), dtype=int)
    nodes_taken_rx = np.zeros(len(nodes), dtype=int)
    nodes_taken_tx = np.zeros(len(nodes), dtype=int)

    demands_sorted = sorted(
        state_t["demands"],
        key=lambda d: d.K_REQ[t],
        reverse=True   # largest demand first
    )
    for d in demands_sorted:
        src = d.n1
        dst = d.n2

        done = 0
        current_node = src
        while done == 0:
            adj_links = sorted(
                (l for l in links
                    if l.n1 == current_node and l.K_MAX[t] >= d.K_REQ[t] and state_t["a"][links.index(l)] <= d.K_REQ[t] and nodes_taken_tx[nodes.index(l.n1)] == 0 and nodes_taken_rx[nodes.index(l.n2)] == 0),
                key=lambda l: l.K_MAX[t],
                reverse=True
            )
            if adj_links != []:
                action[links.index(adj_links[0])] = 1
                current_node = adj_links[0].n2
                nodes_taken_rx[nodes.index(adj_links[0].n2)] = 1
                nodes_taken_tx[nodes.index(adj_links[0].n1)] = 1
            else:
                done = 1
                
            if current_node == dst:
                done = 1

    return action

# ---------- Actor-Critic network for multi-binary action ----------
class ActorCriticBinary(nn.Module):
    def __init__(self, state_dim, action_dim, hidden=128):
        super().__init__()
        # self.net = nn.Sequential(
        #     nn.Linear(state_dim, hidden),
        #     nn.ReLU(),
        #     nn.Linear(hidden, hidden),
        #     nn.ReLU()
        # )
        # # outputs logits for Bernoulli per action dimension
        # self.logit_head = nn.Linear(hidden, action_dim)
        # # critic outputs a scalar value
        # self.critic = nn.Sequential(
        #     nn.Linear(state_dim, hidden//2),
        #     nn.ReLU(),
        #     nn.Linear(hidden//2, 1)
        # )
        self.trunk = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.ReLU(),
            nn.Linear(hidden, hidden),
            nn.LayerNorm(hidden),
            nn.ReLU()
        )
        
        self.actor = nn.Linear(hidden, action_dim)
        self.critic = nn.Linear(hidden, 1)

    def forward(self, state):
        """
        state: tensor of shape [batch, state_dim]
        returns:
            logits: [batch, action_dim]
            value: [batch, 1]
        """
        # h = self.net(state)
        # logits = self.logit_head(h)
        # value = self.critic(state)
        h = self.trunk(state)
        logits = self.actor(h)
        value = self.critic(h).squeeze(-1)
        return logits, value.squeeze(-1)

# ---------- PPO Agent for binary actions ----------
class PPOBinaryAgent:
    def __init__(self, state_dim, action_dim, lr=LR):
        self.model = ActorCriticBinary(state_dim, action_dim).to(DEVICE)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.action_dim = action_dim

    def select_action(self, state_vec, mask=None):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        logits, value = self.model(s)  # [1, action_dim], [1]

        probs = torch.sigmoid(logits)
        m = torch.distributions.Bernoulli(probs)
        action = m.sample()
        logp = m.log_prob(action).sum(dim=-1)

        return action.squeeze(0).cpu().numpy().astype(int), logp.squeeze(0).detach(), value.squeeze(0).detach()

    def evaluate_action(self, state_vec, action_vec):
        """
        Evaluate log-prob and value of a GIVEN action (heuristic or policy).
        """
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        a = torch.tensor(action_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    
        logits, value = self.model(s)
        probs = torch.sigmoid(logits)
    
        dist = torch.distributions.Bernoulli(probs)
        logp = dist.log_prob(a).sum(dim=-1)
    
        return logp.squeeze(0).detach(), value.squeeze(0).detach()

    def compute_gae(self, rewards, values, dones, gamma=GAMMA, lam=GAE_LAMBDA):
        # rewards: list length T
        # values: tensor shape [T+1] containing state values; values[-1] is bootstrap for final
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            delta = rewards[t] + gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + gamma * lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
        returns = adv + values[:-1]
        return adv, returns

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef):  # >>> CHANGE - new param
        """
        states: tensor [N, state_dim]
        actions: tensor [N, action_dim] (0/1)
        old_logps: tensor [N] (scalar log prob of full action vector)
        returns: tensor [N]
        advantages: tensor [N]
        """
        advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        N = states.shape[0]
        idxs = np.arange(N)
        for _ in range(EPOCHS):
            np.random.shuffle(idxs)
            for start in range(0, N, BATCH_SIZE):
                batch_idx = idxs[start:start + BATCH_SIZE]
                b_states = states[batch_idx].to(DEVICE)
                b_actions = actions[batch_idx].to(DEVICE).float()
                b_old_logps = old_logps[batch_idx].to(DEVICE)
                b_returns = returns[batch_idx].to(DEVICE)
                b_adv = advantages[batch_idx].to(DEVICE)

                logits, values = self.model(b_states)
                probs = torch.sigmoid(logits)
                dist = torch.distributions.Bernoulli(probs)
                new_logp = dist.log_prob(b_actions).sum(dim=-1)
                entropy = dist.entropy().sum(dim=-1).mean()

                ratio = torch.exp(new_logp - b_old_logps)
                surr1 = ratio * b_adv
                surr2 = torch.clamp(ratio, 1.0 - CLIP, 1.0 + CLIP) * b_adv
                actor_loss = -torch.min(surr1, surr2).mean()
                critic_loss = F.mse_loss(values, b_returns)

                loss = actor_loss + VALUE_COEF * critic_loss - entropy_coef * entropy  # >>> CHANGE

                self.optimizer.zero_grad()
                loss.backward()

                # ----- MANDATORY FOR GAT -----
                #torch.nn.utils.clip_grad_norm_(self.model.parameters(), 0.5)
                
                self.optimizer.step()

# %%
# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T
action_dim = n_links

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(state[0], links, 0)
state_dim = len(state_vector_example)

agent = PPOBinaryAgent(state_dim, action_dim, lr=LR)

# Training hyperparams
num_episodes = 5000
episode_len = len(syst.T)

# Track total rewards per episode
episode_rewards = []

solution = {"a": state[0]["a"].copy()}

WARM_EPISODES  = 500
DECAY_EPISODES = 2000

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]
    state[0]["demands"] = demands.copy()
    state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf = []
    actions_buf = []
    logps_buf = []
    rewards_buf = []
    dones_buf = []
    values_buf = []

    total_reward = 0.0

    mean_kbps_rand = random.randint(1, 5)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space.append(
        demand(
            k_req_vals,
            gnodes[0], #gnodes[2],
            gnodes[1]  #gnodes[3]
        )
    )
    demands_space.append(
        demand(
            k_req_vals,
            gnodes[2], #gnodes[2],
            gnodes[3]  #gnodes[3]
        )
    )
    demands_space.append(
        demand(
            k_req_vals,
            gnodes[1], #gnodes[2],
            gnodes[2]  #gnodes[3]
        )
    )

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)
    k = random.randint(MIN_DEMANDS, MAX_DEMANDS)
    demands = random.sample(demands_space, k)
    random.shuffle(demands)

    for t in syst.T:
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t)

        #p_h = max(0.0, 1 - ep / DECAY_EPISODES)
        #use_heuristic = (np.random.rand() < p_h)

        # if ep < WARM_EPISODES:
        # #if use_heuristic:
        #     action_vec = heuristic_policy(state[t], links, t)
        
        #     # IMPORTANT: still evaluate logp and value using PPO policy
        #     logp, value = agent.evaluate_action(s_vec, action_vec)
        # else:
        action_vec, logp, value = agent.select_action(s_vec)

        # convert flat action vector to dictionary
        action[t] = {}
        for idx_l in range(n_links):
            action[t][idx_l] = int(action_vec[idx_l])

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes
        for idx_n, n in enumerate(nodes):
            sum_tx[idx_n] = sum(action[t][idx_l]
                                for idx_l, l in enumerate(links)
                                if  l.n1 == n
                               )

            sum_rx[idx_n] = sum(action[t][idx_l]
                                for idx_l, l in enumerate(links)
                                if  l.n2 == n
                               )
            
            check_tx = check_tx and (sum_tx[idx_n] <= n.N_TX)
            check_rx = check_rx and (sum_rx[idx_n] <= n.N_RX)

            # if not check_tx or not check_rx:
            #     # print("Violated maximum RX/TX constraints!")
            #     break

        if check_tx and check_rx:
            
            solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, action, t, 1)
        else:
            reward_t = -sum(sum_tx[idx_n] + sum_rx[idx_n] for idx_n, n in enumerate(nodes)) / len(nodes) / 2 #-10

        reward[t] = reward_t
        total_reward += reward_t

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        actions_buf.append(torch.tensor(action_vec, dtype=torch.float32))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))

        # step to next state
        if t + 1 < episode_len:
            if check_tx and check_rx:
                state[t+1]["a"] = A_next
            else:
                state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(state[-1], links, t)
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor, final_value.view(1)])   # shape [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}")

# === Plot learning curve ===
plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/5000, total reward: -44.250, entropy_coef: 0.0100, demands: 1
# Episode 2/5000, total reward: -46.250, entropy_coef: 0.0100, demands: 2
# Episode 3/5000, total reward: -48.625, entropy_coef: 0.0100, demands: 3
# Episode 4/5000, total reward: -46.750, entropy_coef: 0.0100, demands: 1
# Episode 5/5000, total reward: -45.000, entropy_coef: 0.0100, demands: 2
# Episode 6/5000, total reward: -47.875, entropy_coef: 0.0099, demands: 1
# Episode 7/5000, total reward: -46.000, entropy_coef: 0.0099, demands: 2
# Episode 8/5000, total reward: -46.625, entropy_coef: 0.0099, demands: 2
# Episode 9/5000, total reward: -45.750, entropy_coef: 0.0099, demands: 2
# Episode 10/5000, total reward: -44.875, entropy_coef: 0.0099, demands: 2
# Episode 11/5000, total reward: -45.750, entropy_coef: 0.0099, demands: 3
# Episode 12/5000, total reward: -49.500, entropy_coef: 0.0099, demands: 1
# Episode 13/5000, total reward: -50.375, entropy_coef: 0.0099, demands: 2
# Episode 14/5000, total reward: -46.875, entropy_coef: 0.0099, demands: 3
# Episode 15/5000, total reward: -46.375, entropy_coef: 0.0099, demands: 2
# Episode 16/5000, total reward: -46.875, entropy_coef: 0.0098, demands: 1
# Episode 17/5000, total reward: -48.250, entropy_coef: 0.0098, demands: 1
# Episode 18/5000, total reward: -44.500, entropy_coef: 0.0098, demands: 1
# Episode 19/5000, total reward: -46.875, entropy_coef: 0.0098, demands: 2
# Episode 20/5000, total reward: -44.625, entropy_coef: 0.0098, demands: 2
# Episode 21/5000, total reward: -46.250, entropy_coef: 0.0098, demands: 2
# Episode 22/5000, total reward: -48.500, entropy_coef: 0.0098, demands: 3
# Episode 23/5000, total reward: -50.125, entropy_coef: 0.0098, demands: 3
# Episode 24/5000, total reward: -51.625, entropy_coef: 0.0098, demands: 2
# Episode 2524/5000, total reward: 7.000, entropy_coef: 0.0010, demands: 2
# Episode 2525/5000, total reward: 41.875, entropy_coef: 0.0010, demands: 3
# Episode 2526/5000, total reward: -0.333, entropy_coef: 0.0010, demands: 1
# Episode 2527/5000, total reward: 138.750, entropy_coef: 0.0010, demands: 3
# Episode 2528/5000, total reward: 0.125, entropy_coef: 0.0010, demands: 2
# Episode 2529/5000, total reward: 40.500, entropy_coef: 0.0010, demands: 3
# Episode 2530/5000, total reward: 45.500, entropy_coef: 0.0010, demands: 2
# Episode 2531/5000, total reward: 122.500, entropy_coef: 0.0010, demands: 3
# Episode 2532/5000, total reward: 3.833, entropy_coef: 0.0010, demands: 1
# Episode 2533/5000, total reward: 119.125, entropy_coef: 0.0010, demands: 3
# Episode 2534/5000, total reward: 69.708, entropy_coef: 0.0010, demands: 1
# Episode 2535/5000, total reward: 189.500, entropy_coef: 0.0010, demands: 1
# Episode 2536/5000, total reward: 48.375, entropy_coef: 0.0010, demands: 3
# Episode 2537/5000, total reward: 32.583, entropy_coef: 0.0010, demands: 1
# Episode 2538/5000, total reward: 29.500, entropy_coef: 0.0010, demands: 2
# Episode 2539/5000, total reward: 58.500, entropy_coef: 0.0010, demands: 2
# Episode 2540/5000, total reward: 0.500, entropy_coef: 0.0010, demands: 1
# Episode 2541/5000, total reward: 69.000, entropy_coef: 0.0010, demands: 1
# Episode 2542/5000, total reward: 190.000, entropy_coef: 0.0010, demands: 2
# Episode 2543/5000, total reward: -1.750, entropy_coef: 0.0010, demands: 3
# Episode 2544/5000, total reward: 54.958, entropy_coef: 0.0010, demands: 1
# Episode 2545/5000, total reward: 20.599, entropy_coef: 0.0010, demands: 3
# Episode 2546/5000, total reward: 9.750, entropy_coef: 0.0010, demands: 1
# Episode 2547/5000, total reward: 18.625, entropy_coef: 0.0010, demands: 3
# Episode 2548/5000, total reward: 4.708, entropy_coef: 0.0010, demands: 1
# Episode 2549/5000, total reward: -1.500, entropy_coef: 0.0010, demands: 1
# Episode 2550/5000, total reward: 89.000, entropy_coef: 0.0010, demands: 1
# Episode 2551/5000, total reward: 59.625, entropy_coef: 0.0010, demands: 1
# Episode 2552/5000, total reward: 78.750, entropy_coef: 0.0010, demands: 2
# Episode 2553/5000, total reward: 46.625, entropy_coef: 0.0010, demands: 2
# Episode 2554/5000, total reward: 4.750, entropy_coef: 0.0010, demands: 2
# Episode 2555/5000, total reward: 0.625, entropy_coef: 0.0010, demands: 1
# Episode 2556/5000, total reward: -0.625, entropy_coef: 0.0010, demands: 3
# Episode 2557/5000, total reward: 2.167, entropy_coef: 0.0010, demands: 1
# Episode 2558/5000, total reward: 48.625, entropy_coef: 0.0010, demands: 2
# Episode 2559/5000, total reward: 23.625, entropy_coef: 0.0010, demands: 3
# Episode 2560/5000, total reward: 153.000, entropy_coef: 0.0010, demands: 3
# Episode 2561/5000, total reward: 3.333, entropy_coef: 0.0010, demands: 2
# Episode 2562/5000, total reward: 6.429, entropy_coef: 0.0010, demands: 2
# Episode 2563/5000, total reward: 88.875, entropy_coef: 0.0010, demands: 2
# Episode 2564/5000, total reward: -0.375, entropy_coef: 0.0010, demands: 3
# Episode 2565/5000, total reward: 26.958, entropy_coef: 0.0010, demands: 3
# Episode 2566/5000, total reward: 5.500, entropy_coef: 0.0010, demands: 3
# Episode 2567/5000, total reward: 111.792, entropy_coef: 0.0010, demands: 1
# Episode 2568/5000, total reward: 47.750, entropy_coef: 0.0010, demands: 1
# Episode 2569/5000, total reward: 48.125, entropy_coef: 0.0010, demands: 2
# Episode 2570/5000, total reward: 2.250, entropy_coef: 0.0010, demands: 1
# Episode 2571/5000, total reward: -0.875, entropy_coef: 0.0010, demands: 2
# Episode 2572/5000, total reward: -1.250, entropy_coef: 0.0010, demands: 1
# Episode 2573/5000, total reward: 148.750, entropy_coef: 0.0010, demands: 3
# Episode 2574/5000, total reward: 74.083, entropy_coef: 0.0010, demands: 1
# Episode 2575/5000, total reward: 128.250, entropy_coef: 0.0010, demands: 1
# Episode 2576/5000, total reward: -0.625, entropy_coef: 0.0010, demands: 3
# Episode 2577/5000, total reward: 111.750, entropy_coef: 0.0010, demands: 3
# Episode 2578/5000, total reward: 65.625, entropy_coef: 0.0010, demands: 1
# Episode 2579/5000, total reward: 79.000, entropy_coef: 0.0010, demands: 3
# Episode 2580/5000, total reward: 6.708, entropy_coef: 0.0010, demands: 1
# Episode 2581/5000, total reward: -0.250, entropy_coef: 0.0010, demands: 1
# Episode 2582/5000, total reward: 169.125, entropy_coef: 0.0010, demands: 1
# Episode 2583/5000, total reward: 129.375, entropy_coef: 0.0010, demands: 2
# Episode 2584/5000, total reward: 0.250, entropy_coef: 0.0010, demands: 3
# Episode 2585/5000, total reward: 28.667, entropy_coef: 0.0010, demands: 2
# Episode 2586/5000, total reward: 3.125, entropy_coef: 0.0010, demands: 1
# Episode 2587/5000, total reward: 89.750, entropy_coef: 0.0010, demands: 3
# Episode 2588/5000, total reward: 5.417, entropy_coef: 0.0010, demands: 1
# Episode 2589/5000, total reward: -0.250, entropy_coef: 0.0010, demands: 2
# Episode 2590/5000, total reward: 10.500, entropy_coef: 0.0010, demands: 2
# Episode 2591/5000, total reward: 0.250, entropy_coef: 0.0010, demands: 2
# Episode 2592/5000, total reward: 170.875, entropy_coef: 0.0010, demands: 3
# Episode 2593/5000, total reward: 0.917, entropy_coef: 0.0010, demands: 3
# Episode 2594/5000, total reward: -1.083, entropy_coef: 0.0010, demands: 3
# Episode 2595/5000, total reward: 4.458, entropy_coef: 0.0010, demands: 2
# Episode 2596/5000, total reward: 0.000, entropy_coef: 0.0010, demands: 3
# Episode 2597/5000, total reward: 79.375, entropy_coef: 0.0010, demands: 1
# Episode 2598/5000, total reward: 18.500, entropy_coef: 0.0010, demands: 3
# Episode 2599/5000, total reward: 1.500, entropy_coef: 0.0010, demands: 3
# Episode 2600/5000, total reward: 50.958, entropy_coef: 0.0010, demands: 3
# Episode 2601/5000, total reward: 55.333, entropy_coef: 0.0010, demands: 2
# Episode 2602/5000, total reward: -1.000, entropy_coef: 0.0010, demands: 1
# Episode 2603/5000, total reward: -1.250, entropy_coef: 0.0010, demands: 2
# Episode 2604/5000, total reward: 3.000, entropy_coef: 0.0010, demands: 2
# Episode 2605/5000, total reward: 4.500, entropy_coef: 0.0010, demands: 1
# Episode 2606/5000, total reward: 70.000, entropy_coef: 0.0010, demands: 3
# Episode 2607/5000, total reward: 11.792, entropy_coef: 0.0010, demands: 1
# Episode 2608/5000, total reward: -1.000, entropy_coef: 0.0010, demands: 1
# Episode 2609/5000, total reward: 109.375, entropy_coef: 0.0010, demands: 1
# Episode 2610/5000, total reward: 38.875, entropy_coef: 0.0010, demands: 1
# Episode 2611/5000, total reward: 79.375, entropy_coef: 0.0010, demands: 1
# Episode 2612/5000, total reward: 99.375, entropy_coef: 0.0010, demands: 2
# Episode 2613/5000, total reward: 7.500, entropy_coef: 0.0010, demands: 3
# Episode 2614/5000, total reward: 41.833, entropy_coef: 0.0010, demands: 3
# Episode 2615/5000, total reward: 19.500, entropy_coef: 0.0010, demands: 1
# Episode 2616/5000, total reward: -0.750, entropy_coef: 0.0010, demands: 3
# Episode 2617/5000, total reward: -0.625, entropy_coef: 0.0010, demands: 3
# Episode 2618/5000, total reward: -0.208, entropy_coef: 0.0010, demands: 3
# Episode 2619/5000, total reward: 6.125, entropy_coef: 0.0010, demands: 1
# Episode 2620/5000, total reward: 130.000, entropy_coef: 0.0010, demands: 1
# Episode 2621/5000, total reward: 80.000, entropy_coef: 0.0010, demands: 3
# Episode 2622/5000, total reward: 4.542, entropy_coef: 0.0010, demands: 1
# Episode 2623/5000, total reward: 59.000, entropy_coef: 0.0010, demands: 2
# Episode 2624/5000, total reward: 83.375, entropy_coef: 0.0010, demands: 2
# Episode 2625/5000, total reward: 151.250, entropy_coef: 0.0010, demands: 1
# Episode 2626/5000, total reward: 78.000, entropy_coef: 0.0010, demands: 1
# Episode 2627/5000, total reward: -1.125, entropy_coef: 0.0010, demands: 2
# Episode 2628/5000, total reward: 59.625, entropy_coef: 0.0010, demands: 3
# Episode 2629/5000, total reward: 3.375, entropy_coef: 0.0010, demands: 1
# Episode 2630/5000, total reward: -0.875, entropy_coef: 0.0010, demands: 3
# Episode 2631/5000, total reward: 65.292, entropy_coef: 0.0010, demands: 2
# Episode 2632/5000, total reward: 120.625, entropy_coef: 0.0010, demands: 1
# Episode 2633/5000, total reward: 18.500, entropy_coef: 0.0010, demands: 3
# Episode 2634/5000, total reward: 73.750, entropy_coef: 0.0010, demands: 3
# Episode 2635/5000, total reward: 4.417, entropy_coef: 0.0010, demands: 2
# Episode 2636/5000, total reward: 161.250, entropy_coef: 0.0010, demands: 1
# Episode 2637/5000, total reward: -1.625, entropy_coef: 0.0010, demands: 3
# Episode 2638/5000, total reward: 2.000, entropy_coef: 0.0010, demands: 1
# Episode 2639/5000, total reward: 79.125, entropy_coef: 0.0010, demands: 3
# Episode 2640/5000, total reward: 75.125, entropy_coef: 0.0010, demands: 1
# Episode 2641/5000, total reward: -1.125, entropy_coef: 0.0010, demands: 1
# Episode 2642/5000, total reward: -0.500, entropy_coef: 0.0010, demands: 2
# Episode 2643/5000, total reward: 119.375, entropy_coef: 0.0010, demands: 1
# Episode 2644/5000, total reward: 20.000, entropy_coef: 0.0010, demands: 3
# Episode 2645/5000, total reward: 75.292, entropy_coef: 0.0010, demands: 2
# Episode 2646/5000, total reward: -1.000, entropy_coef: 0.0010, demands: 1
# Episode 2647/5000, total reward: 190.000, entropy_coef: 0.0010, demands: 2
# Episode 2648/5000, total reward: 7.000, entropy_coef: 0.0010, demands: 2
# Episode 2649/5000, total reward: 89.375, entropy_coef: 0.0010, demands: 2
# Episode 2650/5000, total reward: 9.625, entropy_coef: 0.0010, demands: 3
# Episode 2651/5000, total reward: 6.292, entropy_coef: 0.0010, demands: 1
# Episode 2652/5000, total reward: 158.875, entropy_coef: 0.0010, demands: 1
# Episode 2653/5000, total reward: 158.875, entropy_coef: 0.0010, demands: 2
# Episode 2654/5000, total reward: 123.000, entropy_coef: 0.0010, demands: 3
# Episode 2655/5000, total reward: 81.958, entropy_coef: 0.0010, demands: 2
# Episode 2656/5000, total reward: 32.000, entropy_coef: 0.0010, demands: 3
# Episode 2657/5000, total reward: 25.667, entropy_coef: 0.0010, demands: 1
# Episode 2658/5000, total reward: 128.875, entropy_coef: 0.0010, demands: 3
# Episode 2659/5000, total reward: 32.708, entropy_coef: 0.0010, demands: 2
# Episode 2660/5000, total reward: 60.000, entropy_coef: 0.0010, demands: 2
# Episode 2661/5000, total reward: -0.750, entropy_coef: 0.0010, demands: 3
# Episode 2662/5000, total reward: 0.500, entropy_coef: 0.0010, demands: 1
# Episode 2663/5000, total reward: 169.500, entropy_coef: 0.0010, demands: 1
# Episode 2664/5000, total reward: 29.375, entropy_coef: 0.0010, demands: 2
# Episode 2665/5000, total reward: 24.750, entropy_coef: 0.0010, demands: 3
# Episode 2666/5000, total reward: 4.667, entropy_coef: 0.0010, demands: 2
# Episode 2667/5000, total reward: 74.375, entropy_coef: 0.0010, demands: 3
# Episode 2668/5000, total reward: 2.917, entropy_coef: 0.0010, demands: 2
# Episode 2669/5000, total reward: 3.250, entropy_coef: 0.0010, demands: 3
# Episode 2670/5000, total reward: 4.958, entropy_coef: 0.0010, demands: 2
# Episode 2671/5000, total reward: 2.625, entropy_coef: 0.0010, demands: 3
# Episode 2672/5000, total reward: 4.292, entropy_coef: 0.0010, demands: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 118
#     113     # if not check_tx or not check_rx:
#     114     #     # print("Violated maximum RX/TX constraints!")
#     115     #     break
#     117 if check_tx and check_rx:
# --> 118     solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, action, t, 1)
#     119 else:
#     120     reward_t = -sum(sum_tx[idx_n] + sum_rx[idx_n] for idx_n, n in enumerate(nodes)) / len(nodes) / 2 #-10
#
# File ~/Downloads/Backup/HAP-QKD/problems/online.py:169, in online_new(gss, haps, links, state, action, t, f_qkp)
#     159     if t >= 1:
#     160         m.addConstrs(
#     161             (
#     162                 A[idx_l] >= syst.THETA * gp.quicksum(r_2[idx_l, idx_d]
#    (...)    166             ), name="qkp_min_capacity"
#     167         )
# --> 169     m.addConstrs(
#     170         (
#     171             a[idx_l] == syst.THETA * (l.K_MAX[t] * z[idx_l] * KEY_RATE_SCALE - gp.quicksum(r_1[idx_l, idx_d] + r_2[idx_l, idx_d]
#     172                                                                                        for idx_d, d in enumerate(demands)
#     173                                                                                       )
#     174                                         ) * STORAGE_SCALE
#     175             for idx_l, l in enumerate(links)
#     176         ), name="qkp_sequence"
#     177     )
#     179     m.addConstrs(
#     180         (
#     181             A[idx_l] + a[idx_l] >= 0
#     182             for idx_l, l in enumerate(links)
#     183         ), name="positive_storage"
#     184     )
#     185 else:
#
# File src/gurobipy/_model.pyx:4226, in gurobipy._model.Model.addConstrs()
#
# File ~/Downloads/Backup/HAP-QKD/problems/online.py:171, in <genexpr>(.0)
#     159     if t >= 1:
#     160         m.addConstrs(
#     161             (
#     162                 A[idx_l] >= syst.THETA * gp.quicksum(r_2[idx_l, idx_d]
#    (...)    166             ), name="qkp_min_capacity"
#     167         )
#     169     m.addConstrs(
#     170         (
# --> 171             a[idx_l] == syst.THETA * (l.K_MAX[t] * z[idx_l] * KEY_RATE_SCALE - gp.quicksum(r_1[idx_l, idx_d] + r_2[idx_l, idx_d]
#     172                                                                                        for idx_d, d in enumerate(demands)
#     173                                                                                       )
#     174                                         ) * STORAGE_SCALE
#     175             for idx_l, l in enumerate(links)
#     176         ), name="qkp_sequence"
#     177     )
#     179     m.addConstrs(
#     180         (
#     181             A[idx_l] + a[idx_l] >= 0
#     182             for idx_l, l in enumerate(links)
#     183         ), name="positive_storage"
#     184     )
#     185 else:
#
# File src/gurobipy/_helpers.pyx:41, in gurobipy._helpers.quicksum()
#
# File ~/Downloads/Backup/HAP-QKD/problems/online.py:171, in <genexpr>(.0)
#     159     if t >= 1:
#     160         m.addConstrs(
#     161             (
#     162                 A[idx_l] >= syst.THETA * gp.quicksum(r_2[idx_l, idx_d]
#    (...)    166             ), name="qkp_min_capacity"
#     167         )
#     169     m.addConstrs(
#     170         (
# --> 171             a[idx_l] == syst.THETA * (l.K_MAX[t] * z[idx_l] * KEY_RATE_SCALE - gp.quicksum(r_1[idx_l, idx_d] + r_2[idx_l, idx_d]
#     172                                                                                        for idx_d, d in enumerate(demands)
#     173                                                                                       )
#     174                                         ) * STORAGE_SCALE
#     175             for idx_l, l in enumerate(links)
#     176         ), name="qkp_sequence"
#     177     )
#     179     m.addConstrs(
#     180         (
#     181             A[idx_l] + a[idx_l] >= 0
#     182             for idx_l, l in enumerate(links)
#     183         ), name="positive_storage"
#     184     )
#     185 else:
#
# KeyboardInterrupt:

# %%
# === Plot learning curve with running average ===
window = 10                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,4))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=2, label=f"Running Avg (window={window})")
plt.xlabel("Episode")
plt.ylabel("Smoothed Total Reward")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
