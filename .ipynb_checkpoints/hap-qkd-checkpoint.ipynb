# %%
from libraries import *

# %%
gp.setParam("OutputFlag", 1)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2739131
# Academic license - for non-commercial use only - expires 2026-11-14
# Warning: Gurobi version mismatch between Python 12.0.2 and C library 12.0.3
# Set parameter OutputFlag to value 1

# %%
gnodes, hnodes, links, demands = init_setup_real()
# Out:
#      Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0       0.0     279.000000     49.000000  25000.00000
# 1    3600.0     278.974006     49.042329  23672.57558
# 4    7200.0     278.932833     49.055108  22986.64633
# 7   10800.0     278.900893     49.018890  19378.08451
# 10  14400.0     278.989935     48.980466  20387.52864
# 13  18000.0     279.006678     48.992932  21378.46182
# 16  21600.0     279.038680     49.008456  21722.88519
# 19  25200.0     279.061682     49.024487  23068.06755
# 22  28800.0     279.067620     49.034208  22980.28988
# 25  32400.0     279.080779     49.013625  23209.52264
# 28  36000.0     279.075842     48.996233  23206.76795
# 31  39600.0     279.055069     48.999030  23206.48967
# 34  43200.0     279.049362     48.977709  23429.46557
# 37  46800.0     279.054583     49.001266  22740.73417
# 40  50400.0     278.985247     48.953397  21049.70677
# 43  54000.0     278.919923     48.953306  20474.85927
# 46  57600.0     278.939021     48.977959  19860.05593
# 49  61200.0     278.994659     48.965139  19574.35484
# 52  64800.0     279.043770     48.980250  19784.07311
# 55  68400.0     279.089595     48.954722  18975.42547
# 58  72000.0     279.162255     49.008611  19329.06589
# 61  75600.0     279.282568     49.086498  19451.14069
# 64  79200.0     279.469930     49.125324  21958.28937
# 67  82800.0     279.593425     49.128661  24030.70810
# 70  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=23 (24 time steps)
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval [0, 24) fully covered in checkpoint.

# %%
# # Initialize state and action
# state  = [{} for _ in syst.T]
# action = [{} for _ in syst.T]
# reward = [0  for _ in syst.T]

# state[0]["demands"] = demands
# state[0]["a"] = {i: 0 for i in range(len(links))}

# for t in syst.T:
#     # Ensure action[t] exists
#     if action[t] == {}:
#         action[t] = {}
    
#     for idx_l, l in enumerate(links):
#         for idx_d, d in enumerate(state[t]["demands"]):
#             action[t][(idx_l, idx_d)] = 1 if idx_l in [0, 3] and idx_d == 0 else 0

#     solution, reward[t] = online_new(gnodes, hnodes, links, state, action, t, 1)

#     # Prevent index overflow at last t
#     if t + 1 < len(syst.T):
#         state[t+1]["a"] = solution["a"]
#         state[t+1]["demands"] = state[t]["demands"] + demands  # keep same demands or modify as needed

# %%
# solution = offline(gnodes, hnodes, links, demands, 0, 1)

# %%
# sim_vals = [15000 + i*2000 for i in range(10)]

# # Use nested dictionaries: k_req[f][s], k_srv[f][s]
# k_req, k_srv = {0: {}, 1: {}}, {0: {}, 1: {}}

# problem = 1 ## Maximizing demand satisfaction

# for f in [0, 1]:  # 0: Without QKP, 1: With QKP
#     for s in sim_vals:
#         # Assign request rate to all demands
#         demands = []
#         demands.append(generate_demands(gnodes, syst, mean_kbps=s, amp=1, noise_std=0, pattern="sinusoidal")[0])
#         #k_req_vals = [s] * len(syst.T) # 25600 bits/sec
    
#         # # Use in your demand object
#         # demands.append(
#         #     demand(
#         #         k_req_vals,
#         #         gnodes[0], #gnodes[2],
#         #         gnodes[1]  #gnodes[3]
#         #     )
#         # )

#         k_req[f][s] = sum(
#             d.K_REQ[t]
#             for idx_d, d in enumerate(demands)
#             for t in syst.T
#         )

#         # Solve the optimization
#         solution = offline(gnodes, hnodes, links, demands, f, problem)

#         k_srv[f][s] = sum(
#             solution["r_h"][idx_d, t]
#             for idx_d, d in enumerate(demands)
#             for t in syst.T
#         )

# # --- Plotting ---
# plt.figure(figsize=(6,4))

# # Plot for both scenarios
# for f, label, color, style in [
#     (0, "Without QKP", "tab:blue", "-o"),
#     (1, "With QKP", "tab:orange", "--s")
# ]:
#     x_vals = [k_req[f][s] for s in sim_vals]
#     y_vals = [k_srv[f][s] for s in sim_vals]
#     plt.plot(x_vals, y_vals, style, color=color, linewidth=1.8, label=label)

# # Optional: ideal line y = x
# max_x = max(max(k_req[0].values()), max(k_req[1].values()))
# plt.plot([0, max_x], [0, max_x], 'k--', linewidth=1, label="Ideal (y = x)")

# plt.xlabel("Total Requested Key Rate")
# plt.ylabel("Total Served Key Rate")
# plt.title("Served vs. Requested Key Rate (With and Without QKP)")
# plt.legend()
# plt.grid(True, linestyle="--", alpha=0.6)
# plt.tight_layout()
# plt.show()

# %%
# history = {}
# for t in range(5):
#     solution, history = online(history, gss, haps, links, demands, t)
#     print_solution(solution)
#     #plot_solution(solution)

# %%
# "FREE", "FIXED", "INIT"
solution = placement(gnodes, hnodes, links)
# print_solution(solution)
plot_solution(solution)
# Out:
# Set parameter MIPGap to value 0.01
# Set parameter MIPGapAbs to value 0.01
# Set parameter FeasibilityTol to value 0.01
# Set parameter IntFeasTol to value 0.01
# Set parameter OptimalityTol to value 0.01
# Set parameter Presolve to value 2
# Set parameter Method to value 2
# Set parameter Cuts to value 2
# Set parameter Heuristics to value 0.25
# Set parameter MIPFocus to value 1
# Set parameter NumericFocus to value 1
# Set parameter Threads to value 0
# Set parameter NodefileStart to value 0.5
# Set parameter NoRelHeurTime to value 20
# Set parameter ConcurrentMIP to value 1
# Gurobi Optimizer version 12.0.3 build v12.0.3rc0 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: Intel(R) Core(TM) Ultra 9 275HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 24 physical cores, 24 logical processors, using up to 24 threads
#
# Non-default parameters:
# FeasibilityTol  0.01
# IntFeasTol  0.01
# MIPGap  0.01
# MIPGapAbs  0.01
# OptimalityTol  0.01
# Method  2
# Heuristics  0.25
# MIPFocus  1
# NodefileStart  0.5
# NoRelHeurTime  20
# Cuts  2
# NumericFocus  1
# Presolve  2
#
# Optimize a model with 478 rows, 528 columns and 1340 nonzeros
# Model fingerprint: 0x850977e8
# Model has 96 quadratic constraints
# Model has 96 simple general constraints
#   96 PWL
# Variable types: 336 continuous, 192 integer (192 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+07]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [5e+01, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+02]
#   RHS range        [1e-01, 1e+07]
#   QRHS range       [4e+03, 1e+04]
#   PWLCon x range   [1e+02, 1e+02]
#   PWLCon y range   [1e+02, 1e+02]
# Presolve removed 48 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 430 rows, 528 columns, 1052 nonzeros
# Presolved model has 96 quadratic constraint(s)
# Variable types: 432 continuous, 96 integer (96 binary)
# Starting NoRel heuristic
# Found phase-1 solution: relaxation 1.49273e+06
# Found phase-1 solution: relaxation 1.47455e+06
# Found phase-1 solution: relaxation 1.45991e+06
# Found phase-1 solution: relaxation 1.43078e+06
# Found heuristic solution: objective 5062025.9077
# Found phase-1 solution: relaxation 0 (96 lazy constraints)
# Transition to phase 2
# Elapsed time for NoRel heuristic: 5s (best bound 9.07667e+06)
# Elapsed time for NoRel heuristic: 11s (best bound 9.07667e+06)
# Elapsed time for NoRel heuristic: 16s (best bound 9.07667e+06)
# NoRel heuristic complete
# Root relaxation presolve removed 238 rows and 142 columns
# Root relaxation presolved: 288 rows, 386 columns, 864 nonzeros
#
# Root barrier log...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4
#  78993 67822 5977181.84   44   62 5062027.52 6340697.89  25.3%  66.5  218s
#  80180 69336 5817047.67   52   54 5062027.52 6340697.89  25.3%  66.5  224s
#  81904 72066 5839061.01   48   58 5062027.52 6333855.68  25.1%  66.6  230s
#  84937 74583 5828763.49   48   58 5062027.52 6329922.10  25.0%  66.8  236s
#  87762 76128 5361787.72   48   58 5062027.52 6329921.40  25.0%  66.8  241s
#  89585 77024 5988055.51   36   70 5062027.52 6329921.40  25.0%  66.8  247s
#  90641 79047 5616798.81   52   54 5062027.52 6329921.40  25.0%  66.9  253s
#  92978 80501 5771167.02   55   51 5062027.52 6326290.83  25.0%  67.0  259s
#  94638 82541 6044561.66   34   72 5062027.52 6326290.83  25.0%  67.1  265s
#  96960 84452 5560834.32   65   41 5062027.52 6322852.63  24.9%  67.2  271s
#  99173 85740 6092499.49   34   72 5062027.52 6322706.17  24.9%  67.3  277s
#  100587 87239 5722714.58   62   44 5062027.52 6322706.17  24.9%  67.4  283s
#  102236 89903 6087070.75   31   75 5062027.52 6322706.17  24.9%  67.5  289s

# %%
demands = []
demands.append(generate_demands(gnodes, syst, mean_kbps=20, amp=1, noise_std=0, pattern="sinusoidal")[0])

demand_feasibility(gnodes, demands)

# %%
# plot_key_rate_stratotegic(1, 0, 0, 0)

# %%
# plot_transmittance_stratotegic_real()

# %%
# plot_loss_distance(1, 0, 0, 0)

# %%
# plot_loss_fog()

# %%
# plot_loss_rain()

# %%
# from balloon_qnet.QEuropeFunctions import *
# import balloon_qnet.transmittance as transmittance
# from balloon_qnet.free_space_losses import DownlinkChannel, compute_channel_length, CachedChannel
# import multiprocessing as mlp
# import os
# import functools as fnct

# # Parameters
# wavelength = 1550e-9
# zenith_angle = 0
# ground_station_alt = 0.020 #Altitude of the receiving telescope
# obs_ratio_ground = 0.3 #Obscuration ratio of the receiving telescope same
# Cn0 = 9.6*10**(-14) #Reference index of refraction structure constant at ground level
# u_rms = 10 #Wind speed
# pointing_error = 1e-6 #Pointing error variance
# Qonnector_meas_succ = 0.85 #Detector efficiency at the receiver
# tracking_efficiency = 0.8 # Tracking efficiency
# rx_aperture_ground = 0.3 #Aperture of the receiving telescope 
# W0 = 0.1 #Initial Beam Waist 

# h_balloons = 18 #Altitude range of the balloon
# n_max_ground = [2,3,4,5,6,7,8,9,10] #Maximum radial index of correction of AO system 

# simtime = 500000 #Simulation time

# RE = 6371 # Earth's radius [km]
# c = 299792458 

# def compute_channel_length(ground_station_alt, aerial_platform_alt, zenith_angle):
#     """Compute channel length that corresponds to a particular ground station altitude, aerial 
#     platform altitude and zenith angle.

#     ## Parameters
#         `ground_station_alt` : float 
#             Altitude of the ground station [km].
#         `aerial_platform_alt` : float 
#             Altitude of the aerial platform [km].
#         `zenith_angle` : float
#             Zenith angle of aerial platform [degrees].
#     ## Returns
#     `length` : float
#         Length of the channel [km].
#     """
#     zenith_angle = np.deg2rad(zenith_angle)
#     RA = RE + aerial_platform_alt
#     RG = RE + ground_station_alt
#     length = np.sqrt(RA**2 + RG**2*(np.cos(zenith_angle)**2 - 1)) - RG*np.cos(zenith_angle)
#     return length

# def heightTheo(h_balloons,n):
    
#     height_balloon = compute_channel_length(ground_station_alt, h_balloons, zenith_angle)
#     transmittance_down = transmittance.slant(ground_station_alt, h_balloons, wavelength*1e9, zenith_angle)
    
  
#     downlink_channel = DownlinkChannel(W0, rx_aperture_ground, obs_ratio_ground, n, Cn0, u_rms, wavelength, ground_station_alt, h_balloons, zenith_angle,
#                                             pointing_error = pointing_error, tracking_efficiency = tracking_efficiency, Tatm = transmittance_down)
#     eta = np.arange(1e-7, 1, 0.001)
#     mean = downlink_channel._compute_mean_channel_efficiency(eta, height_balloon, detector_efficiency = Qonnector_meas_succ)
#     print("Theoretical mean " + str(mean) + " with AO " + str(n))
#     return mean
    
    
# #Simulated mean transmittance

# def heightSimu(h_balloons,n):
    
#     height_balloon = compute_channel_length(ground_station_alt, h_balloons, zenith_angle)
#     transmittance_down = transmittance.slant(ground_station_alt, h_balloons, wavelength*1e9, zenith_angle)
#     # Initialize network
#     net = QEurope("Europe")

#     # Create quantum City 1
#     net.Add_Qonnector("QonnectorCity1")

#     # Create drone 1
#     net.Add_Qonnector("QonnectorDroneCity1")

#     downlink_channel = DownlinkChannel(W0, rx_aperture_ground, obs_ratio_ground, n, Cn0, u_rms, wavelength, ground_station_alt, h_balloons, zenith_angle,
#                                             pointing_error = pointing_error, tracking_efficiency = tracking_efficiency, Tatm = transmittance_down)
#     a = downlink_channel._compute_loss_probability(height_balloon,math.ceil(simtime/Qonnector_init_time ))


#     downlink = CachedChannel(a)
    
#     # Connect nodes
#     net.connect_qonnectors("QonnectorCity1", "QonnectorDroneCity1", distance = height_balloon, loss_model = downlink)

#     # Get node instances
#     city = net.network.get_node("QonnectorCity1")
#     balloon = net.network.get_node("QonnectorDroneCity1")

#     # BB84 from city 1 to drone 1
#     send = SendBB84(city, Qonnector_init_succ, Qonnector_init_flip, balloon)
#     send.start()
#     receive = ReceiveProtocol(balloon, Qonnector_meas_succ, Qonnector_meas_flip, True, city)
#     receive.start()


#     # Run simulation
#     stat = ns.sim_run(duration = simtime)

#     # Display and results 
#     L1 = Sifting(balloon.QlientKeys[city.name], city.QlientKeys[balloon.name])
#     chan_eff = len(city.QlientKeys[balloon.name])/len(balloon.QlientKeys[city.name])

#     print("Height of the balloon: "+str(h_balloons)+"km")
#     print("AO : " + str(n))
#     print("Number of qubits sent by the Balloon: " +str(len(balloon.QlientKeys[city.name])) )
#     print("Number of qubits received by Bob (Qlient): " +str(len(city.QlientKeys[balloon.name])) )
#     print("Channel efficiency : "+str(chan_eff) + " bits per channel use")
    
#     return chan_eff

# res = []
# for n in n_max_ground:
#     res.append([h_balloons,n,'simu',heightSimu(h_balloons,n),'theo',heightTheo(h_balloons,n)])

# %%
# eff = ts.simulate_downlink(18, 99, 10)
# ts.compute_skr(eff)
# eff = ts.simulate_uplink(18, 99, 10)
# ts.compute_skr(eff)

# %%
# ts.channel_simulation("downlink", 0, 25.00000001, 55.96577044616698, 6, simtime=10000)
